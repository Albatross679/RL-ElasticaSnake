# %%
# **Step 2: The Python Script (`train_snake.py`)**

import gymnasium as gym
from gymnasium import spaces
import numpy as np
import elastica as ea
from collections import defaultdict
from typing import Optional
from numpy.typing import NDArray
# from PyElastica.elastica.timestepper.symplectic_steppers import do_step
# from PyElastica.elastica.timestepper import extend_stepper_interface
from elastica.typing import RodType


from stable_baselines3 import PPO
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.callbacks import BaseCallback

import matplotlib.pyplot as plt

import os

# %%
class BaseContinuumSnakeEnv(gym.Env):
    """
    Shared implementation for the PyElastica Continuum Snake Gymnasium environment.
    Subclasses configure how wavelength is handled in the action space.
    """
    metadata = {"render_modes": []}

    def __init__(self, obs_keys: Optional[list] = None):
        super().__init__()

        self._n_elem = 50
        self._torque_min = 1e-3
        self._torque_max = 8e-3
        self._torque_span = self._torque_max - self._torque_min

        action_space_low, action_space_high = self._action_space_bounds()
        self.action_space = spaces.Box(low=action_space_low, high=action_space_high, dtype=np.float32)

        if obs_keys is None:
            obs_keys = ["position", "velocity", "director"]
        self.obs_keys = obs_keys

        valid_keys = [
            "time",
            "avg_position",
            "avg_velocity",
            "curvature",
            "tangents",
            "position",
            "velocity",
            "director",
        ]
        for key in self.obs_keys:
            if key not in valid_keys:
                raise ValueError(f"Invalid observation key: {key}. Valid keys are: {valid_keys}")

        obs_size = self._calculate_obs_size()
        self.observation_space = spaces.Box(-np.inf, np.inf, shape=(obs_size,), dtype=np.float32)

        self.period = 2.0
        self.ratio_time = 11.0
        self.time_step = 1e-4
        self.rut_ratio = 1
        self.slip_velocity_tol = 1e-8

        self.start = np.zeros((3,))
        self.direction = np.array([0.0, 0.0, 1.0])
        self.normal = np.array([0.0, 1.0, 0.0])
        self.base_length = 0.35
        self.base_radius = self.base_length * 0.011
        self.density = 1000
        self.E = 1e6
        self.poisson_ratio = 0.5
        self.shear_modulus = self.E / (1.0 + self.poisson_ratio)

        self.timestepper = ea.PositionVerlet()

        self.current_time = 0.0
        self.state_dict = {
            "time": [],
            "avg_position": [],
            "avg_velocity": [],
            "curvature": [],
            "tangents": [],
            "position": [],
            "velocity": [],
            "director": [],
            "torque_coeffs": [],
            "wave_number": [],
            "forward": [],
            "lateral": [],
            "reward": [],
        }

        self._prev_com = None
        self._dir = np.array([0.0, 0.0, 1.0], dtype=np.float64)
        self.forward = 0.0
        self.lateral = 0.0

        target = np.array([1.0, 0.0, 1.0], dtype=np.float64)
        self.target_direction = target / (np.linalg.norm(target) + 1e-12)
        self.required_alignment_steps = 15 #3
        self.alignment_angle_tolerance = np.deg2rad(5.0)
        self._alignment_dot_threshold = np.cos(self.alignment_angle_tolerance)
        self.alignment_speed_tol = 1e-4
        self._alignment_streak = 0
        self.velocity_projection = 0.0
        self._last_velocity_vec = np.zeros(3, dtype=np.float64)

        self.reward_weights = {
            "forward_progress": 1.0,
            "lateral_penalty": 0.2,
            "curvature_penalty": 0.05,
            "energy_penalty": 2.0e4,
            "smoothness_penalty": 5.0e3,
            "alignment_bonus": 0.5,
            "streak_bonus": 1.0,
        }
        self._prev_torque_coeffs = None

        self.callback_data = defaultdict(list)

    def _action_space_bounds(self) -> tuple[NDArray[np.float32], NDArray[np.float32]]:
        raise NotImplementedError

    def _default_action(self) -> NDArray[np.float64]:
        raise NotImplementedError

    def _map_action_to_torque(self, action: NDArray[np.float64]) -> NDArray[np.float64]:
        action_arr = np.clip(np.asarray(action, dtype=np.float64), -1.0, 1.0)
        magnitudes = self._torque_max - self._torque_span * np.abs(action_arr)
        torques = np.sign(action_arr) * magnitudes
        torques[np.isclose(action_arr, 0.0)] = 0.0
        return torques.astype(np.float64)

    def _map_torque_to_action(self, torque: NDArray[np.float64]) -> NDArray[np.float64]:
        torque_arr = np.asarray(torque, dtype=np.float64)
        magnitudes = np.abs(torque_arr)
        clipped = np.clip(magnitudes, 0.0, self._torque_max)
        abs_action = (self._torque_max - clipped) / self._torque_span
        abs_action = np.clip(abs_action, 0.0, 1.0)
        return (abs_action * np.sign(torque_arr)).astype(np.float64)

    def _augment_action(self, action: NDArray[np.float64]) -> NDArray[np.float64]:
        raise NotImplementedError

    @staticmethod
    def _default_torque_coeffs() -> NDArray[np.float64]:
        return np.array([3.4e-3, 3.3e-3, 4.2e-3, 2.6e-3, 3.6e-3, 3.5e-3], dtype=np.float64)

    def _calculate_obs_size(self) -> int:
        n_elem = self._n_elem
        n_nodes = n_elem + 1
        key_sizes = {
            "time": 1,
            "avg_position": 3,
            "avg_velocity": 3,
            "curvature": (n_elem - 1) * 3,
            "tangents": n_elem * 3,
            "position": n_nodes * 3,
            "velocity": n_nodes * 3,
            "director": n_elem * 9,
        }
        return sum(key_sizes[key] for key in self.obs_keys)

    def _transition_model(self, b_coeff: NDArray[np.float64]):
        class SnakeSimulator(
            ea.BaseSystemCollection,
            ea.Constraints,
            ea.Forcing,
            ea.Damping,
            ea.CallBacks,
            ea.Contact,
        ):
            pass

        snake_sim = SnakeSimulator()
        snake_sim.append(self.shearable_rod)

        gravitational_acc = -9.80665
        snake_sim.add_forcing_to(self.shearable_rod).using(
            ea.GravityForces, acc_gravity=np.array([0.0, gravitational_acc, 0.0])
        )

        wave_length = b_coeff[-1]
        b_coeff_only = b_coeff[:-1]
        snake_sim.add_forcing_to(self.shearable_rod).using(
            ea.MuscleTorques,
            base_length=self.base_length,
            b_coeff=b_coeff_only,
            period=self.period,
            wave_number=2.0 * np.pi / wave_length,
            phase_shift=0.0,
            rest_lengths=self.shearable_rod.rest_lengths,
            ramp_up_time=self.rut_ratio * self.period,
            direction=self.normal,
            with_spline=True,
        )

        ground_plane = ea.Plane(
            plane_origin=np.array([0.0, -self.base_radius, 0.0]),
            plane_normal=self.normal,
        )
        snake_sim.append(ground_plane)
        froude = 0.1
        mu = self.base_length / (self.period * self.period * np.abs(gravitational_acc) * froude)
        kinetic_mu_array = np.array([mu, 1.5 * mu, 2.0 * mu])  # [forward, backward, sideways]
        static_mu_array = np.zeros(kinetic_mu_array.shape)
        snake_sim.detect_contact_between(self.shearable_rod, ground_plane).using(
            ea.RodPlaneContactWithAnisotropicFriction,
            k=1.0,
            nu=1e-6,
            slip_velocity_tol=self.slip_velocity_tol,
            static_mu_array=static_mu_array,
            kinetic_mu_array=kinetic_mu_array,
        )

        damping_constant = 2e-3
        snake_sim.dampen(self.shearable_rod).using(
            ea.AnalyticalLinearDamper,
            damping_constant=damping_constant,
            time_step=self.time_step,
        )

        if not hasattr(self, "callback_data") or self.callback_data is None:
            self.callback_data = defaultdict(list)
        rendering_fps = 60
        step_skip = int(1.0 / (rendering_fps * self.time_step))
        slip_velocity_tol = self.slip_velocity_tol

        class ContinuumSnakeCallBack(ea.CallBackBaseClass):
            def __init__(self, step_skip: int, callback_params: dict) -> None:
                ea.CallBackBaseClass.__init__(self)
                self.every = step_skip
                self.callback_params = callback_params

            def make_callback(
                self, system: ea.CosseratRod, time: float, current_step: int
            ) -> None:
                if current_step == 0:
                    return

                if current_step % self.every == 0:
                    self.callback_params["time"].append(time)
                    self.callback_params["step"].append(current_step)
                    self.callback_params["position"].append(
                        system.position_collection.copy()
                    )
                    self.callback_params["velocity"].append(
                        system.velocity_collection.copy()
                    )
                    self.callback_params["avg_velocity"].append(
                        system.compute_velocity_center_of_mass()
                    )
                    self.callback_params["center_of_mass"].append(
                        system.compute_position_center_of_mass()
                    )
                    self.callback_params["curvature"].append(system.kappa.copy())
                    self.callback_params["tangents"].append(system.tangents.copy())
                    self.callback_params["friction"].append(
                        self.get_slip_velocity(system).copy()
                    )
                    return

            def get_slip_velocity(self, system: RodType) -> NDArray[np.float64]:
                from elastica.contact_utils import (
                    _find_slipping_elements,
                    _node_to_element_velocity,
                )
                from elastica._linalg import _batch_dot, _batch_product_k_ik_to_ik

                axial_direction = system.tangents
                element_velocity = _node_to_element_velocity(
                    mass=system.mass, node_velocity_collection=system.velocity_collection
                )
                velocity_mag_along_axial_direction = _batch_dot(
                    element_velocity, axial_direction
                )
                velocity_along_axial_direction = _batch_product_k_ik_to_ik(
                    velocity_mag_along_axial_direction, axial_direction
                )
                return _find_slipping_elements(
                    velocity_along_axial_direction, slip_velocity_tol
                )

        snake_sim.collect_diagnostics(self.shearable_rod).using(
            ContinuumSnakeCallBack,
            step_skip=step_skip,
            callback_params=self.callback_data,
        )

        snake_sim.finalize()
        return snake_sim

    def _get_obs_value_from_rod(self, key: str):
        if key == "position":
            return self.shearable_rod.position_collection.ravel()
        if key == "velocity":
            return self.shearable_rod.velocity_collection.ravel()
        if key == "director":
            return self.shearable_rod.director_collection.ravel()
        if key == "curvature":
            return self.shearable_rod.kappa.ravel()
        if key == "tangents":
            return self.shearable_rod.tangents.ravel()
        if key == "avg_position":
            return self.shearable_rod.compute_position_center_of_mass()
        if key == "avg_velocity":
            return self.shearable_rod.compute_velocity_center_of_mass()
        if key == "time":
            return np.array([self.current_time])
        raise ValueError(f"Unknown observation key: {key}")

    def _get_obs(self):
        obs_parts = []
        use_state_dict = (
            len(self.obs_keys) > 0
            and self.obs_keys[0] in self.state_dict
            and len(self.state_dict[self.obs_keys[0]]) > 0
        )

        for key in self.obs_keys:
            if use_state_dict and key in self.state_dict and len(self.state_dict[key]) > 0:
                latest_value = self.state_dict[key][-1]
                if isinstance(latest_value, np.ndarray):
                    obs_parts.append(latest_value.ravel())
                else:
                    obs_parts.append(np.array([latest_value]))
            else:
                obs_parts.append(self._get_obs_value_from_rod(key))

        return np.concatenate(obs_parts).astype(np.float32)

    def reset(self, seed: Optional[int] = None, options: Optional[dict] = None):
        super().reset(seed=seed)

        self.current_time = 0.0
        self.state_dict = {
            "time": [],
            "avg_position": [],
            "avg_velocity": [],
            "curvature": [],
            "tangents": [],
            "position": [],
            "velocity": [],
            "director": [],
            "torque_coeffs": [],
            "wave_number": [],
            "forward": [],
            "lateral": [],
            "reward": [],
        }

        self._prev_com = None
        self._dir = np.array([0.0, 0.0, 1.0], dtype=np.float64)
        self.forward = 0.0
        self.lateral = 0.0
        self.reward = 0.0
        self.velocity_projection = 0.0
        self._alignment_streak = 0
        self._last_velocity_vec = np.zeros(3, dtype=np.float64)
        self._prev_torque_coeffs = None

        self.callback_data = defaultdict(list)

        self.shearable_rod = ea.CosseratRod.straight_rod(
            self._n_elem,
            self.start,
            self.direction,
            self.normal,
            self.base_length,
            self.base_radius,
            self.density,
            youngs_modulus=self.E,
            shear_modulus=self.shear_modulus,
        )

        reset_action = self._default_action()
        if options is not None and "action" in options:
            reset_action = np.asarray(options["action"], dtype=np.float64)
        reset_action = np.asarray(reset_action, dtype=np.float64)
        b_coeff = self._augment_action(reset_action)

        self.sim = self._transition_model(b_coeff)

        observation = self._get_obs()
        info = {}
        return observation, info

    def _forward_lateral_from_last_step(
        self, sim_time: float
    ) -> tuple[float, float, NDArray[np.float64]]:
        com = self.shearable_rod.compute_position_center_of_mass()
        if self._prev_com is None:
            self._prev_com = com.copy()
            return 0.0, 0.0, np.zeros(3, dtype=np.float64)

        disp = com - self._prev_com
        velocity_vec = disp / (sim_time + 1e-12)
        new_dir = velocity_vec / (np.linalg.norm(velocity_vec) + 1e-12)
        alpha = 1.0
        self._dir = (1 - alpha) * self._dir + alpha * new_dir
        self._dir /= np.linalg.norm(self._dir) + 1e-12

        forward = float(np.dot(velocity_vec, self._dir))
        lateral = float(
            np.linalg.norm(velocity_vec - np.dot(velocity_vec, self._dir) * self._dir)
        )

        self._prev_com = com.copy()
        return forward, lateral, velocity_vec

    def step(self, action):
        action = np.asarray(action, dtype=np.float64)
        b_coeff = self._augment_action(action)

        sim_time = (self.ratio_time + 0.001) * self.period
        total_steps = int(sim_time / self.time_step)

        self.sim = self._transition_model(b_coeff)

        prev_com_before = (
            self.shearable_rod.compute_position_center_of_mass().copy()
            if self._prev_com is None
            else self._prev_com.copy()
        )

        self.current_time = ea.integrate(
            self.timestepper,
            self.sim,
            sim_time,
            total_steps,
            self.current_time,
            progress_bar=False,
        )

        self.state_dict["time"].append(self.current_time)
        self.state_dict["avg_position"].append(
            self.shearable_rod.compute_position_center_of_mass()
        )
        self.state_dict["avg_velocity"].append(
            self.shearable_rod.compute_velocity_center_of_mass()
        )
        self.state_dict["curvature"].append(self.shearable_rod.kappa.copy())
        self.state_dict["tangents"].append(self.shearable_rod.tangents.copy())
        self.state_dict["position"].append(
            self.shearable_rod.position_collection.copy()
        )
        self.state_dict["velocity"].append(
            self.shearable_rod.velocity_collection.copy()
        )
        self.state_dict["director"].append(
            self.shearable_rod.director_collection.copy()
        )

        self._prev_com = prev_com_before
        self.forward, self.lateral, velocity_vec = self._forward_lateral_from_last_step(sim_time)
        self._last_velocity_vec = velocity_vec
        current_com = self.shearable_rod.compute_position_center_of_mass()
        self.velocity_projection = float(np.dot(velocity_vec, self.target_direction))

        speed = float(np.linalg.norm(velocity_vec))
        alignment = 0.0
        if speed > self.alignment_speed_tol:
            alignment = float(
                np.dot(velocity_vec / (speed + 1e-12), self.target_direction)
            )
        if speed > self.alignment_speed_tol and alignment >= self._alignment_dot_threshold:
            self._alignment_streak += 1
        else:
            self._alignment_streak = 0

        torque_coeffs = b_coeff[:-1].astype(np.float64).copy()
        forward_progress = float(np.dot(current_com - prev_com_before, self.target_direction))
        forward_term = self.reward_weights["forward_progress"] * forward_progress
        lateral_penalty = -self.reward_weights["lateral_penalty"] * float(self.lateral)
        curvature_array = self.shearable_rod.kappa
        curvature_magnitude = (
            float(np.mean(np.linalg.norm(curvature_array, axis=0))) if curvature_array.size > 0 else 0.0
        )
        curvature_penalty = -self.reward_weights["curvature_penalty"] * curvature_magnitude
        energy_penalty = -self.reward_weights["energy_penalty"] * float(np.linalg.norm(torque_coeffs) ** 2)

        smoothness_penalty = 0.0
        if self._prev_torque_coeffs is not None:
            delta_torque = torque_coeffs - self._prev_torque_coeffs
            smoothness_penalty = -self.reward_weights["smoothness_penalty"] * float(
                np.linalg.norm(delta_torque) ** 2
            )

        alignment_bonus = 0.0
        if speed > self.alignment_speed_tol and alignment > 0.0:
            alignment_bonus += self.reward_weights["alignment_bonus"] * alignment
            if self._alignment_streak >= self.required_alignment_steps:
                alignment_bonus += self.reward_weights["streak_bonus"]

        reward_terms = {
            "forward_progress": float(forward_term),
            "lateral_penalty": float(lateral_penalty),
            "curvature_penalty": float(curvature_penalty),
            "energy_penalty": float(energy_penalty),
            "smoothness_penalty": float(smoothness_penalty),
            "alignment_bonus": float(alignment_bonus),
        }

        self.reward = float(sum(reward_terms.values()))
        reward = float(self.reward)
        self._prev_torque_coeffs = torque_coeffs.copy()

        self.state_dict["torque_coeffs"].append(torque_coeffs.copy())
        self.state_dict["wave_number"].append(2.0 * np.pi / b_coeff[-1])
        self.state_dict["forward"].append(float(self.forward))
        self.state_dict["lateral"].append(float(self.lateral))
        self.state_dict["reward"].append(float(self.reward))

        max_sim_time = 300
        terminated_due_to_time = self.current_time >= max_sim_time
        terminated_due_to_alignment = self._alignment_streak >= self.required_alignment_steps
        # terminated_due_to_alignment = False
        terminated = terminated_due_to_time or terminated_due_to_alignment
        truncated = False

        observation = self._get_obs()

        info = {}
        info["reward"] = float(reward)
        info["reward_terms"] = reward_terms
        info["forward_speed"] = float(self.forward)
        info["lateral_speed"] = float(self.lateral)
        info["velocity_projection"] = float(self.velocity_projection)
        info["forward_progress"] = forward_progress
        info["speed"] = speed
        info["alignment"] = alignment
        info["alignment_streak"] = int(self._alignment_streak)
        info["alignment_goal_met"] = bool(terminated_due_to_alignment)
        info["position"] = current_com.astype(float)
        info["heading_dir"] = self._dir.astype(float)
        info["current_time"] = float(self.current_time)

        return observation, reward, terminated, truncated, info

    def close(self):
        pass


class FixedWavelengthContinuumSnakeEnv(BaseContinuumSnakeEnv):
    def __init__(self, fixed_wavelength: float, obs_keys: Optional[list] = None):
        self.fixed_wavelength = float(fixed_wavelength)
        super().__init__(obs_keys=obs_keys)

    def _action_space_bounds(self) -> tuple[NDArray[np.float32], NDArray[np.float32]]:
        low = -np.ones(6, dtype=np.float32)
        high = np.ones(6, dtype=np.float32)
        return low, high

    def _default_action(self) -> NDArray[np.float64]:
        torques = self._default_torque_coeffs()
        return self._map_torque_to_action(torques)

    def _augment_action(self, action: NDArray[np.float64]) -> NDArray[np.float64]:
        if action.shape[-1] != 6:
            raise ValueError("Expected 6 torque coefficients for fixed-wavelength control.")
        torques = self._map_action_to_torque(action)
        return np.append(torques, self.fixed_wavelength)


class VariableWavelengthContinuumSnakeEnv(BaseContinuumSnakeEnv):
    def __init__(
        self,
        obs_keys: Optional[list] = None,
        wavelength_bounds: tuple[float, float] = (-1.5, 1.5),
        default_wavelength: float = 1.0,
    ):
        self.wavelength_bounds = wavelength_bounds
        self.default_wavelength = default_wavelength
        super().__init__(obs_keys=obs_keys)

    def _action_space_bounds(self) -> tuple[NDArray[np.float32], NDArray[np.float32]]:
        low = -np.ones(7, dtype=np.float32)
        high = np.ones(7, dtype=np.float32)
        low[-1] = np.float32(self.wavelength_bounds[0])
        high[-1] = np.float32(self.wavelength_bounds[1])
        return low, high

    def _default_action(self) -> NDArray[np.float64]:
        torques = self._default_torque_coeffs()
        torque_actions = self._map_torque_to_action(torques)
        return np.append(torque_actions, self.default_wavelength)

    def _augment_action(self, action: NDArray[np.float64]) -> NDArray[np.float64]:
        if action.shape[-1] != 7:
            raise ValueError(
                "Expected 7 action dimensions (6 torque coefficients + wavelength)."
            )
        action = np.asarray(action, dtype=np.float64).copy()
        torques = self._map_action_to_torque(action[:-1])
        min_w, max_w = self.wavelength_bounds
        wavelength = float(np.clip(action[-1], min_w, max_w))
        return np.append(torques, wavelength)

# %%
# Create environment with fixed wavelength (action space size 6)
# To allow modifiable wavelength (action space size 7), use VariableWavelengthContinuumSnakeEnv.

# Customize the observation/state space by editing this list of keys.
# Set to None to fall back to the default keys defined in BaseContinuumSnakeEnv.
custom_obs_keys = [
    "position",
    "velocity",
    "curvature",
]

env = FixedWavelengthContinuumSnakeEnv(
    fixed_wavelength=1.0,
    obs_keys=custom_obs_keys,
    
)
env.reset()

# Verify action space is now size 6
print(f"Action space shape: {env.action_space.shape}")
print(f"Fixed wavelength: {env.fixed_wavelength}")
print(f"Observation space shape: {env.observation_space.shape}")
print(f"Observation keys: {env.obs_keys}")

env.period = 1
env.ratio_time = 0.01
env.rut_ratio = 0.001
# Out:
# Action space shape: (6,)
# Fixed wavelength: 1.0
# Observation space shape: (453,)
# Observation keys: ['position', 'velocity', 'curvature']

# %% [markdown]
# constant input

# %%
# Run 30 steps using the default action
num_steps = 30

# Get default action based on environment configuration
# default_action = np.array([3.4e-3, 3.3e-3, 4.2e-3, 2.6e-3, 3.6e-3, 3.5e-3], dtype=np.float32)
# default_action = np.array([3e-3, 3e-3, 3e-3, 3e-3, 3e-3, 3e-3], dtype=np.float32)
# default_action = np.array([1e-2, 1e-2, 1e-2, 1e-2, 1e-2, 1e-2], dtype=np.float32)
# default_action = np.array([5e-3, 5e-3, 5e-3, 5e-3, 5e-3, 5e-3], dtype=np.float32)
default_action = np.array([-5e-3, 5e-3, 5e-3, 5e-3, -5e-3, -5e-3], dtype=np.float32)
# default_action = np.array([-9.9e-3, 9.9e-3, 9.9e-3, 9.9e-3, -9.9e-3, -9.9e-3], dtype=np.float32)
# default_action = np.array([-1e-2, 1e-2, 1e-2, 1e-2, -1e-2, -1e-2], dtype=np.float32)
# default_action = np.array([5e-4, 5e-4, 5e-4, 5e-4, 5e-4, 5e-4], dtype=np.float32)
# default_action = np.array([1e-3, 1e-3, 1e-3, 1e-3, 1e-3, 1e-3], dtype=np.float32)
# default_action = np.array([3e-3, 5e-3, 4e-3, 3.5e-3, 3e-3, 2e-3], dtype=np.float32)
# default_action = np.array([5e-3, 4e-3, 3.5e-3, 3e-3, 2e-3, 1e-3], dtype=np.float32)



action = env._map_torque_to_action(default_action)
print(action)
# Out:
# [-0.42857144  0.42857144  0.42857144  0.42857144 -0.42857144 -0.42857144]

# %%
# Run simulation steps
for i in range(num_steps):
    obs, reward, terminated, truncated, info = env.step(action)
    print(f"Step {i+1}/{num_steps}: time={info['current_time']:.2f}s, "
          f"forward={info['forward_speed']:.4f} m/s, "
          f"lateral={info['lateral_speed']:.4f} m/s, "
          f"reward={info['reward']:.4f}")
    
    if terminated or truncated:
        print(f"Simulation ended at step {i+1}")
        break
# Out:
# Step 1/30: time=0.01s, forward=0.0020 m/s, lateral=0.0000 m/s, reward=-3.1667
# Step 2/30: time=0.02s, forward=0.0047 m/s, lateral=0.0000 m/s, reward=-3.1811
# Step 3/30: time=0.03s, forward=0.0074 m/s, lateral=0.0000 m/s, reward=-3.4748
# Step 4/30: time=0.04s, forward=0.0038 m/s, lateral=0.0000 m/s, reward=-3.5757
# Step 5/30: time=0.05s, forward=0.0076 m/s, lateral=0.0000 m/s, reward=-3.6263
# Step 6/30: time=0.07s, forward=0.0143 m/s, lateral=0.0000 m/s, reward=-3.6433
# Step 7/30: time=0.08s, forward=0.0206 m/s, lateral=0.0000 m/s, reward=-3.6559
# Step 8/30: time=0.09s, forward=0.0269 m/s, lateral=0.0000 m/s, reward=-3.6730
# Step 9/30: time=0.10s, forward=0.0324 m/s, lateral=0.0000 m/s, reward=-3.7109
# Step 10/30: time=0.11s, forward=0.0375 m/s, lateral=0.0000 m/s, reward=-3.7454
# Step 11/30: time=0.12s, forward=0.0413 m/s, lateral=0.0000 m/s, reward=-3.7563
# Step 12/30: time=0.13s, forward=0.0431 m/s, lateral=0.0000 m/s, reward=-3.7346
# Step 13/30: time=0.14s, forward=0.0441 m/s, lateral=0.0000 m/s, reward=-3.6890
# Step 14/30: time=0.15s, forward=0.0438 m/s, lateral=0.0000 m/s, reward=-3.6344
# Step 15/30: time=0.17s, forward=0.0433 m/s, lateral=0.0000 m/s, reward=-3.5898
# Step 16/30: time=0.18s, forward=0.0478 m/s, lateral=0.0000 m/s, reward=-3.5831
# Step 17/30: time=0.19s, forward=0.0586 m/s, lateral=0.0000 m/s, reward=-3.5996
# Step 18/30: time=0.20s, forward=0.0689 m/s, lateral=0.0000 m/s, reward=-3.6432
# Step 19/30: time=0.21s, forward=0.0725 m/s, lateral=0.0000 m/s, reward=-3.6589
# Step 20/30: time=0.22s, forward=0.0717 m/s, lateral=0.0000 m/s, reward=-3.6581
# Step 21/30: time=0.23s, forward=0.0686 m/s, lateral=0.0000 m/s, reward=-3.6480
# Step 22/30: time=0.24s, forward=0.0625 m/s, lateral=0.0000 m/s, reward=-3.6552
# Step 23/30: time=0.25s, forward=0.0511 m/s, lateral=0.0000 m/s, reward=-3.6716
# Step 24/30: time=0.26s, forward=0.0375 m/s, lateral=0.0000 m/s, reward=-3.6840
# Step 25/30: time=0.28s, forward=0.0251 m/s, lateral=0.0000 m/s, reward=-3.6895
# Step 26/30: time=0.29s, forward=0.0142 m/s, lateral=0.0000 m/s, reward=-3.5644
# Step 27/30: time=0.30s, forward=0.0085 m/s, lateral=0.0000 m/s, reward=-3.2448
# Step 28/30: time=0.31s, forward=0.0072 m/s, lateral=0.0000 m/s, reward=-3.1698
# Step 29/30: time=0.32s, forward=0.0043 m/s, lateral=0.0000 m/s, reward=-3.1881
# Step 30/30: time=0.33s, forward=0.0055 m/s, lateral=0.0000 m/s, reward=-3.6517

# %% [markdown]
# visulization

# %%
from visualization import visualization

v1 = visualization()

# %%
# Visualize trajectory in 2D (X vs Z)
avg_positions = np.asarray(env.state_dict['avg_position'])
# v1.trajectory_2d(avg_positions[:, 0], avg_positions[:, 2])

# Visualize velocity norm history
avg_velocities = np.asarray(env.state_dict['avg_velocity'])
# v1.velocity_norm_history(env.state_dict['time'], avg_velocities)

# Visualize trajectory in 3D
# v1.trajectory_3d(avg_positions)

# v1.trajectory_2d(avg_positions[:, 0], avg_positions[:, 2])


# plt.plot(env.state_dict['time'], env.state_dict['torque_coeffs'])
# plt.plot(env.state_dict['time'], env.state_dict['reward'])


# Visualize current snake shape
# v1.current_shape_3d(env.shearable_rod)

# Plot video from callback data
# v1.plot_video(env.callback_data)
# v1.plot_video_limited( 
#                       env.callback_data,
#                       "video_limited1.mp4",
#                       1500
#                       )
v1.plot_video_auto_limits(
    env.callback_data,
    "video_auto_limits.mp4",
    1500,
)
# Out:
# Plotting limited video: using 1500 of 3611 frames, 24.80 fps, 60.48 seconds duration
# 100%|██████████| 1499/1499 [00:17<00:00, 86.21it/s]

# %% [markdown]
# check on a dictionary

# %%
# Print shapes of all keys in callback_data
print("Shapes of all keys in env.callback_data:")
print("=" * 50)
for key in sorted(env.callback_data.keys()):
    data = env.callback_data[key]
    if len(data) > 0:
        shape = np.asarray(data).shape
        print(f"{key:20s}: {shape}")
    else:
        print(f"{key:20s}: (empty)")
print("=" * 50)
# Out:
# Shapes of all keys in env.callback_data:
# ==================================================
# avg_velocity        : (19, 3)
# center_of_mass      : (19, 3)
# curvature           : (19, 3, 49)
# friction            : (19, 50)
# position            : (19, 3, 51)
# step                : (19,)
# tangents            : (19, 3, 50)
# time                : (19,)
# velocity            : (19, 3, 51)
# ==================================================

# %%
log_path = os.path.join("Training", "Logs")
model = PPO(
    "MlpPolicy",
    env,
    verbose=1,
    # tensorboard_log=log_path
)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
# Custom callback to print rewards during training
class RewardCallback(BaseCallback):
    """
    Callback for printing reward information during training.
    Prints episode rewards and, optionally, step-level metrics.
    """
    def __init__(
        self,
        verbose: int = 0,
        print_freq: int = 5,
        step_print_interval: Optional[int] = None,
        step_info_keys: Optional[list[str]] = None,
    ):
        super(RewardCallback, self).__init__(verbose)
        self.print_freq = print_freq
        self.step_print_interval = step_print_interval
        self.step_info_keys = step_info_keys or []
        self.episode_rewards = []
        self.episode_lengths = []
        self.step_rewards = []
        self.episode_count = 0

    def _on_step(self) -> bool:
        rewards = self.locals.get('rewards', [0])
        infos = self.locals.get('infos', [{}])

        if len(rewards) > 0:
            step_reward = float(np.mean(rewards))
            self.step_rewards.append(step_reward)

            if self.step_print_interval and self.num_timesteps % self.step_print_interval == 0:
                info_dict = infos[0] if len(infos) > 0 and isinstance(infos[0], dict) else {}
                info_bits = []
                for key in self.step_info_keys:
                    if key in info_dict:
                        info_bits.append(f"{key}={info_dict[key]}")
                info_suffix = f" | {'; '.join(info_bits)}" if info_bits else ""
                print(f"[Step {self.num_timesteps}] reward={step_reward:.6f}{info_suffix}")

        if len(infos) > 0 and isinstance(infos[0], dict):
            if 'episode' in infos[0]:
                episode_info = infos[0]['episode']
                if episode_info is not None:
                    episode_reward = episode_info.get('r', 0)
                    episode_length = episode_info.get('l', 0)
                    self.episode_rewards.append(episode_reward)
                    self.episode_lengths.append(episode_length)
                    self.episode_count += 1

                    print(
                        f"\n[Episode {self.episode_count}] "
                        f"Reward = {episode_reward:.4f}, "
                        f"Length = {episode_length} steps"
                    )

                    if self.episode_count % self.print_freq == 0:
                        avg_reward = np.mean(self.episode_rewards[-self.print_freq:])
                        print(f"  -> Average reward (last {self.print_freq} episodes) = {avg_reward:.4f}\n")

        return True

# %%
total_training_timesteps = 2000
# total_training_timesteps = 50_000
print(f"Starting training for {total_training_timesteps} timesteps...")

# Create callback to print rewards
reward_callback = RewardCallback(print_freq=5, step_print_interval=20)  # Print every 5 steps

# Train with callback
model.learn(total_timesteps=total_training_timesteps, callback=reward_callback)
# Out:
# Starting training for 2000 timesteps...
# Final time of simulation is :  0.010999999999999987
# Final time of simulation is :  0.022000000000000193
# Final time of simulation is :  0.03300000000000044
# Final time of simulation is :  0.044000000000000046
# Final time of simulation is :  0.05499999999999965
# Final time of simulation is :  0.06599999999999974
# Final time of simulation is :  0.07700000000000086
# Final time of simulation is :  0.08800000000000198
# Final time of simulation is :  0.0990000000000031
# Final time of simulation is :  0.11000000000000422
# Final time of simulation is :  0.12100000000000534
# Final time of simulation is :  0.13200000000000645
# Final time of simulation is :  0.14300000000000757
# Final time of simulation is :  0.15400000000000869
# Final time of simulation is :  0.1650000000000098
# Final time of simulation is :  0.17600000000001093
# Final time of simulation is :  0.18700000000001205
# Final time of simulation is :  0.19800000000001317
# Final time of simulation is :  0.20900000000001429
# Final time of simulation is :  0.2200000000000154
# [Step 20] reward=-3.413374
# Final time of simulation is :  0.23100000000001653
# Final time of simulation is :  0.24200000000001765
# Final time of simulation is :  0.25300000000001877
# Final time of simulation is :  0.2640000000000199
# Final time of simulation is :  0.275000000000021
# Final time of simulation is :  0.2860000000000221
# Final time of simulation is :  0.29700000000002325
# Final time of simulation is :  0.30800000000002437
# Final time of simulation is :  0.3190000000000255
# Final time of simulation is :  0.3300000000000266
# Final time of simulation is :  0.3410000000000277
# Final time of simulation is :  0.35200000000002885
# Final time of simulation is :  0.36300000000002997
# Final time of simulation is :  0.3740000000000311
# Final time of simulation is :  0.3850000000000322
# Final time of simulation is :  0.3960000000000333
# Final time of simulation is :  0.40700000000003445
# Final time of simulation is :  0.41800000000003557
# Final time of simulation is :  0.4290000000000367
# Final time of simulation is :  0.4400000000000378
# [Step 40] reward=-4.992057
# Final time of simulation is :  0.4510000000000389
# Final time of simulation is :  0.46200000000004005
# Final time of simulation is :  0.47300000000004117
# Final time of simulation is :  0.4840000000000423
# Final time of simulation is :  0.4950000000000434
# Final time of simulation is :  0.506000000000038
# Final time of simulation is :  0.517000000000027
# Final time of simulation is :  0.528000000000016
# Final time of simulation is :  0.539000000000005
# Final time of simulation is :  0.549999999999994
# Final time of simulation is :  0.5609999999999831
# Final time of simulation is :  0.5719999999999721
# Final time of simulation is :  0.5829999999999611
# Final time of simulation is :  0.5939999999999501
# Final time of simulation is :  0.6049999999999391
# Final time of simulation is :  0.6159999999999282
# Final time of simulation is :  0.6269999999999172
# Final time of simulation is :  0.6379999999999062
# Final time of simulation is :  0.6489999999998952
# Final time of simulation is :  0.6599999999998842
# [Step 60] reward=-4.604680
# Final time of simulation is :  0.6709999999998733
# Final time of simulation is :  0.6819999999998623
# Final time of simulation is :  0.6929999999998513
# Final time of simulation is :  0.7039999999998403
# Final time of simulation is :  0.7149999999998293
# Final time of simulation is :  0.7259999999998183
# Final time of simulation is :  0.7369999999998074
# Final time of simulation is :  0.7479999999997964
# Final time of simulation is :  0.7589999999997854
# Final time of simulation is :  0.7699999999997744
# Final time of simulation is :  0.7809999999997634
# Final time of simulation is :  0.7919999999997525
# Final time of simulation is :  0.8029999999997415
# Final time of simulation is :  0.8139999999997305
# Final time of simulation is :  0.8249999999997195
# Final time of simulation is :  0.8359999999997085
# Final time of simulation is :  0.8469999999996976
# Final time of simulation is :  0.8579999999996866
# Final time of simulation is :  0.8689999999996756
# Final time of simulation is :  0.8799999999996646
# [Step 80] reward=-3.280538
# Final time of simulation is :  0.8909999999996536
# Final time of simulation is :  0.9019999999996426
# Final time of simulation is :  0.9129999999996317
# Final time of simulation is :  0.9239999999996207
# Final time of simulation is :  0.9349999999996097
# Final time of simulation is :  0.9459999999995987
# Final time of simulation is :  0.9569999999995877
# Final time of simulation is :  0.9679999999995768
# Final time of simulation is :  0.9789999999995658
# Final time of simulation is :  0.9899999999995548
# Final time of simulation is :  1.0009999999995438
# Final time of simulation is :  1.0119999999995328
# Final time of simulation is :  1.0229999999995218
# Final time of simulation is :  1.0339999999995109
# Final time of simulation is :  1.0449999999994999
# Final time of simulation is :  1.055999999999489
# Final time of simulation is :  1.066999999999478
# Final time of simulation is :  1.077999999999467
# Final time of simulation is :  1.088999999999456
# Final time of simulation is :  1.099999999999445
# [Step 100] reward=-4.636532
# Final time of simulation is :  1.110999999999434
# Final time of simulation is :  1.121999999999423
# Final time of simulation is :  1.132999999999412
# Final time of simulation is :  1.143999999999401
# Final time of simulation is :  1.15499999999939
# Final time of simulation is :  1.165999999999379
# Final time of simulation is :  1.176999999999368
# Final time of simulation is :  1.1879999999993571
# Final time of simulation is :  1.1989999999993461
# Final time of simulation is :  1.2099999999993352
# Final time of simulation is :  1.2209999999993242
# Final time of simulation is :  1.2319999999993132
# Final time of simulation is :  1.2429999999993022
# Final time of simulation is :  1.2539999999992912
# Final time of simulation is :  1.2649999999992803
# Final time of simulation is :  1.2759999999992693
# Final time of simulation is :  1.2869999999992583
# Final time of simulation is :  1.2979999999992473
# Final time of simulation is :  1.3089999999992363
# Final time of simulation is :  1.3199999999992253
# [Step 120] reward=-3.248028
# Final time of simulation is :  1.3309999999992144
# Final time of simulation is :  1.3419999999992034
# Final time of simulation is :  1.3529999999991924
# Final time of simulation is :  1.3639999999991814
# Final time of simulation is :  1.3749999999991704
# Final time of simulation is :  1.3859999999991595
# Final time of simulation is :  1.3969999999991485
# Final time of simulation is :  1.4079999999991375
# Final time of simulation is :  1.4189999999991265
# Final time of simulation is :  1.4299999999991155
# Final time of simulation is :  1.4409999999991046
# Final time of simulation is :  1.4519999999990936
# Final time of simulation is :  1.4629999999990826
# Final time of simulation is :  1.4739999999990716
# Final time of simulation is :  1.4849999999990606
# Final time of simulation is :  1.4959999999990496
# Final time of simulation is :  1.5069999999990387
# Final time of simulation is :  1.5179999999990277
# Final time of simulation is :  1.5289999999990167
# Final time of simulation is :  1.5399999999990057
# [Step 140] reward=-2.815036
# Final time of simulation is :  1.5509999999989947
# Final time of simulation is :  1.5619999999989838
# Final time of simulation is :  1.5729999999989728
# Final time of simulation is :  1.5839999999989618
# Final time of simulation is :  1.5949999999989508
# Final time of simulation is :  1.6059999999989398
# Final time of simulation is :  1.6169999999989288
# Final time of simulation is :  1.6279999999989179
# Final time of simulation is :  1.6389999999989069
# Final time of simulation is :  1.649999999998896
# Final time of simulation is :  1.660999999998885
# Final time of simulation is :  1.671999999998874
# Final time of simulation is :  1.682999999998863
# Final time of simulation is :  1.693999999998852
# Final time of simulation is :  1.704999999998841
# Final time of simulation is :  1.71599999999883
# Final time of simulation is :  1.726999999998819
# Final time of simulation is :  1.737999999998808
# Final time of simulation is :  1.748999999998797
# Final time of simulation is :  1.759999999998786
# [Step 160] reward=-2.475254
# Final time of simulation is :  1.770999999998775
# Final time of simulation is :  1.7819999999987641
# Final time of simulation is :  1.7929999999987531
# Final time of simulation is :  1.8039999999987422
# Final time of simulation is :  1.8149999999987312
# Final time of simulation is :  1.8259999999987202
# Final time of simulation is :  1.8369999999987092
# Final time of simulation is :  1.8479999999986982
# Final time of simulation is :  1.8589999999986873
# Final time of simulation is :  1.8699999999986763
# Final time of simulation is :  1.8809999999986653
# Final time of simulation is :  1.8919999999986543
# Final time of simulation is :  1.9029999999986433
# Final time of simulation is :  1.9139999999986324
# Final time of simulation is :  1.9249999999986214
# Final time of simulation is :  1.9359999999986104
# Final time of simulation is :  1.9469999999985994
# Final time of simulation is :  1.9579999999985884
# Final time of simulation is :  1.9689999999985774
# Final time of simulation is :  1.9799999999985665
# [Step 180] reward=-3.409706
# Final time of simulation is :  1.9909999999985555
# Final time of simulation is :  2.0019999999985534
# Final time of simulation is :  2.012999999998591
# Final time of simulation is :  2.0239999999986282
# Final time of simulation is :  2.0349999999986657
# Final time of simulation is :  2.045999999998703
# Final time of simulation is :  2.0569999999987405
# Final time of simulation is :  2.067999999998778
# Final time of simulation is :  2.0789999999988154
# Final time of simulation is :  2.0899999999988528
# Final time of simulation is :  2.10099999999889
# Final time of simulation is :  2.1119999999989276
# Final time of simulation is :  2.122999999998965
# Final time of simulation is :  2.1339999999990025
# Final time of simulation is :  2.14499999999904
# Final time of simulation is :  2.1559999999990773
# Final time of simulation is :  2.1669999999991147
# Final time of simulation is :  2.177999999999152
# Final time of simulation is :  2.1889999999991896
# Final time of simulation is :  2.199999999999227
# [Step 200] reward=-3.116331
# Final time of simulation is :  2.2109999999992644
# Final time of simulation is :  2.221999999999302
# Final time of simulation is :  2.2329999999993393
# Final time of simulation is :  2.2439999999993767
# Final time of simulation is :  2.254999999999414
# Final time of simulation is :  2.2659999999994516
# Final time of simulation is :  2.276999999999489
# Final time of simulation is :  2.2879999999995264
# Final time of simulation is :  2.298999999999564
# Final time of simulation is :  2.3099999999996013
# Final time of simulation is :  2.3209999999996387
# Final time of simulation is :  2.331999999999676
# Final time of simulation is :  2.3429999999997135
# Final time of simulation is :  2.353999999999751
# Final time of simulation is :  2.3649999999997884
# Final time of simulation is :  2.375999999999826
# Final time of simulation is :  2.3869999999998632
# Final time of simulation is :  2.3979999999999007
# Final time of simulation is :  2.408999999999938
# Final time of simulation is :  2.4199999999999755
# [Step 220] reward=-2.162874
# Final time of simulation is :  2.431000000000013
# Final time of simulation is :  2.4420000000000504
# Final time of simulation is :  2.4530000000000878
# Final time of simulation is :  2.464000000000125
# Final time of simulation is :  2.4750000000001626
# Final time of simulation is :  2.4860000000002
# Final time of simulation is :  2.4970000000002375
# Final time of simulation is :  2.508000000000275
# Final time of simulation is :  2.5190000000003123
# Final time of simulation is :  2.5300000000003497
# Final time of simulation is :  2.541000000000387
# Final time of simulation is :  2.5520000000004246
# Final time of simulation is :  2.563000000000462
# Final time of simulation is :  2.5740000000004994
# Final time of simulation is :  2.585000000000537
# Final time of simulation is :  2.5960000000005743
# Final time of simulation is :  2.6070000000006117
# Final time of simulation is :  2.618000000000649
# Final time of simulation is :  2.6290000000006866
# Final time of simulation is :  2.640000000000724
# [Step 240] reward=-3.065188
# Final time of simulation is :  2.6510000000007614
# Final time of simulation is :  2.662000000000799
# Final time of simulation is :  2.6730000000008363
# Final time of simulation is :  2.6840000000008737
# Final time of simulation is :  2.695000000000911
# Final time of simulation is :  2.7060000000009485
# Final time of simulation is :  2.717000000000986
# Final time of simulation is :  2.7280000000010234
# Final time of simulation is :  2.739000000001061
# Final time of simulation is :  2.7500000000010982
# Final time of simulation is :  2.7610000000011357
# Final time of simulation is :  2.772000000001173
# Final time of simulation is :  2.7830000000012105
# Final time of simulation is :  2.794000000001248
# Final time of simulation is :  2.8050000000012854
# Final time of simulation is :  2.816000000001323
# Final time of simulation is :  2.82700000000136
# Final time of simulation is :  2.8380000000013976
# Final time of simulation is :  2.849000000001435
# Final time of simulation is :  2.8600000000014725
# [Step 260] reward=-4.936665
# Final time of simulation is :  2.87100000000151
# Final time of simulation is :  2.8820000000015473
# Final time of simulation is :  2.8930000000015847
# Final time of simulation is :  2.904000000001622
# Final time of simulation is :  2.9150000000016596
# Final time of simulation is :  2.926000000001697
# Final time of simulation is :  2.9370000000017344
# Final time of simulation is :  2.948000000001772
# Final time of simulation is :  2.9590000000018093
# Final time of simulation is :  2.9700000000018467
# Final time of simulation is :  2.981000000001884
# Final time of simulation is :  2.9920000000019216
# Final time of simulation is :  3.003000000001959
# Final time of simulation is :  3.0140000000019964
# Final time of simulation is :  3.025000000002034
# Final time of simulation is :  3.0360000000020713
# Final time of simulation is :  3.0470000000021087
# Final time of simulation is :  3.058000000002146
# Final time of simulation is :  3.0690000000021835
# Final time of simulation is :  3.080000000002221
# [Step 280] reward=-5.915164
# Final time of simulation is :  3.0910000000022584
# Final time of simulation is :  3.102000000002296
# Final time of simulation is :  3.1130000000023332
# Final time of simulation is :  3.1240000000023707
# Final time of simulation is :  3.135000000002408
# Final time of simulation is :  3.1460000000024455
# Final time of simulation is :  3.157000000002483
# Final time of simulation is :  3.1680000000025204
# Final time of simulation is :  3.179000000002558
# Final time of simulation is :  3.190000000002595
# Final time of simulation is :  3.2010000000026326
# Final time of simulation is :  3.21200000000267
# Final time of simulation is :  3.2230000000027075
# Final time of simulation is :  3.234000000002745
# Final time of simulation is :  3.2450000000027823
# Final time of simulation is :  3.2560000000028197
# Final time of simulation is :  3.267000000002857
# Final time of simulation is :  3.2780000000028946
# Final time of simulation is :  3.289000000002932
# Final time of simulation is :  3.3000000000029694
# [Step 300] reward=-4.447101
# Final time of simulation is :  3.311000000003007
# Final time of simulation is :  3.3220000000030443
# Final time of simulation is :  3.3330000000030817
# Final time of simulation is :  3.344000000003119
# Final time of simulation is :  3.3550000000031566
# Final time of simulation is :  3.366000000003194
# Final time of simulation is :  3.3770000000032314
# Final time of simulation is :  3.388000000003269
# Final time of simulation is :  3.3990000000033063
# Final time of simulation is :  3.4100000000033437
# Final time of simulation is :  3.421000000003381
# Final time of simulation is :  3.4320000000034185
# Final time of simulation is :  3.443000000003456
# Final time of simulation is :  3.4540000000034934
# Final time of simulation is :  3.465000000003531
# Final time of simulation is :  3.4760000000035682
# Final time of simulation is :  3.4870000000036057
# Final time of simulation is :  3.498000000003643
# Final time of simulation is :  3.5090000000036805
# Final time of simulation is :  3.520000000003718
# [Step 320] reward=-4.522535
# Final time of simulation is :  3.5310000000037554
# Final time of simulation is :  3.542000000003793
# Final time of simulation is :  3.55300000000383
# Final time of simulation is :  3.5640000000038676
# Final time of simulation is :  3.575000000003905
# Final time of simulation is :  3.5860000000039425
# Final time of simulation is :  3.59700000000398
# Final time of simulation is :  3.6080000000040173
# Final time of simulation is :  3.6190000000040548
# Final time of simulation is :  3.630000000004092
# Final time of simulation is :  3.6410000000041296
# Final time of simulation is :  3.652000000004167
# Final time of simulation is :  3.6630000000042044
# Final time of simulation is :  3.674000000004242
# Final time of simulation is :  3.6850000000042793
# Final time of simulation is :  3.6960000000043167
# Final time of simulation is :  3.707000000004354
# Final time of simulation is :  3.7180000000043916
# Final time of simulation is :  3.729000000004429
# Final time of simulation is :  3.7400000000044664
# [Step 340] reward=-4.537583
# Final time of simulation is :  3.751000000004504
# Final time of simulation is :  3.7620000000045413
# Final time of simulation is :  3.7730000000045787
# Final time of simulation is :  3.784000000004616
# Final time of simulation is :  3.7950000000046535
# Final time of simulation is :  3.806000000004691
# Final time of simulation is :  3.8170000000047284
# Final time of simulation is :  3.828000000004766
# Final time of simulation is :  3.8390000000048032
# Final time of simulation is :  3.8500000000048407
# Final time of simulation is :  3.861000000004878
# Final time of simulation is :  3.8720000000049155
# Final time of simulation is :  3.883000000004953
# Final time of simulation is :  3.8940000000049904
# Final time of simulation is :  3.905000000005028
# Final time of simulation is :  3.916000000005065
# Final time of simulation is :  3.9270000000051026
# Final time of simulation is :  3.93800000000514
# Final time of simulation is :  3.9490000000051775
# Final time of simulation is :  3.960000000005215
# [Step 360] reward=-6.759782
# Final time of simulation is :  3.9710000000052523
# Final time of simulation is :  3.9820000000052898
# Final time of simulation is :  3.993000000005327
# Final time of simulation is :  4.0040000000053295
# Final time of simulation is :  4.01500000000527
# Final time of simulation is :  4.026000000005211
# Final time of simulation is :  4.037000000005151
# Final time of simulation is :  4.048000000005092
# Final time of simulation is :  4.059000000005033
# Final time of simulation is :  4.070000000004973
# Final time of simulation is :  4.081000000004914
# Final time of simulation is :  4.092000000004854
# Final time of simulation is :  4.103000000004795
# Final time of simulation is :  4.114000000004736
# Final time of simulation is :  4.125000000004676
# Final time of simulation is :  4.136000000004617
# Final time of simulation is :  4.1470000000045575
# Final time of simulation is :  4.158000000004498
# Final time of simulation is :  4.169000000004439
# Final time of simulation is :  4.180000000004379
# [Step 380] reward=-3.833260
# Final time of simulation is :  4.19100000000432
# Final time of simulation is :  4.2020000000042605
# Final time of simulation is :  4.213000000004201
# Final time of simulation is :  4.224000000004142
# Final time of simulation is :  4.235000000004082
# Final time of simulation is :  4.246000000004023
# Final time of simulation is :  4.257000000003964
# Final time of simulation is :  4.268000000003904
# Final time of simulation is :  4.279000000003845
# Final time of simulation is :  4.2900000000037855
# Final time of simulation is :  4.301000000003726
# Final time of simulation is :  4.312000000003667
# Final time of simulation is :  4.323000000003607
# Final time of simulation is :  4.334000000003548
# Final time of simulation is :  4.3450000000034885
# Final time of simulation is :  4.356000000003429
# Final time of simulation is :  4.36700000000337
# Final time of simulation is :  4.37800000000331
# Final time of simulation is :  4.389000000003251
# Final time of simulation is :  4.400000000003192
# [Step 400] reward=-4.826411
# Final time of simulation is :  4.411000000003132
# Final time of simulation is :  4.422000000003073
# Final time of simulation is :  4.433000000003013
# Final time of simulation is :  4.444000000002954
# Final time of simulation is :  4.455000000002895
# Final time of simulation is :  4.466000000002835
# Final time of simulation is :  4.477000000002776
# Final time of simulation is :  4.4880000000027165
# Final time of simulation is :  4.499000000002657
# Final time of simulation is :  4.510000000002598
# Final time of simulation is :  4.521000000002538
# Final time of simulation is :  4.532000000002479
# Final time of simulation is :  4.5430000000024195
# Final time of simulation is :  4.55400000000236
# Final time of simulation is :  4.565000000002301
# Final time of simulation is :  4.576000000002241
# Final time of simulation is :  4.587000000002182
# Final time of simulation is :  4.598000000002123
# Final time of simulation is :  4.609000000002063
# Final time of simulation is :  4.620000000002004
# [Step 420] reward=-2.840080
# Final time of simulation is :  4.6310000000019444
# Final time of simulation is :  4.642000000001885
# Final time of simulation is :  4.653000000001826
# Final time of simulation is :  4.664000000001766
# Final time of simulation is :  4.675000000001707
# Final time of simulation is :  4.6860000000016475
# Final time of simulation is :  4.697000000001588
# Final time of simulation is :  4.708000000001529
# Final time of simulation is :  4.719000000001469
# Final time of simulation is :  4.73000000000141
# Final time of simulation is :  4.741000000001351
# Final time of simulation is :  4.752000000001291
# Final time of simulation is :  4.763000000001232
# Final time of simulation is :  4.774000000001172
# Final time of simulation is :  4.785000000001113
# Final time of simulation is :  4.796000000001054
# Final time of simulation is :  4.807000000000994
# Final time of simulation is :  4.818000000000935
# Final time of simulation is :  4.8290000000008755
# Final time of simulation is :  4.840000000000816
# [Step 440] reward=-1.799134
# Final time of simulation is :  4.851000000000757
# Final time of simulation is :  4.862000000000697
# Final time of simulation is :  4.873000000000638
# Final time of simulation is :  4.8840000000005785
# Final time of simulation is :  4.895000000000519
# Final time of simulation is :  4.90600000000046
# Final time of simulation is :  4.9170000000004
# Final time of simulation is :  4.928000000000341
# Final time of simulation is :  4.939000000000282
# Final time of simulation is :  4.950000000000222
# Final time of simulation is :  4.961000000000163
# Final time of simulation is :  4.9720000000001034
# Final time of simulation is :  4.983000000000044
# Final time of simulation is :  4.993999999999985
# Final time of simulation is :  5.004999999999925
# Final time of simulation is :  5.015999999999866
# Final time of simulation is :  5.0269999999998065
# Final time of simulation is :  5.037999999999747
# Final time of simulation is :  5.048999999999688
# Final time of simulation is :  5.059999999999628
# [Step 460] reward=-5.161078
# Final time of simulation is :  5.070999999999569
# Final time of simulation is :  5.08199999999951
# Final time of simulation is :  5.09299999999945
# Final time of simulation is :  5.103999999999391
# Final time of simulation is :  5.114999999999331
# Final time of simulation is :  5.125999999999272
# Final time of simulation is :  5.136999999999213
# Final time of simulation is :  5.147999999999153
# Final time of simulation is :  5.158999999999094
# Final time of simulation is :  5.1699999999990345
# Final time of simulation is :  5.180999999998975
# Final time of simulation is :  5.191999999998916
# Final time of simulation is :  5.202999999998856
# Final time of simulation is :  5.213999999998797
# Final time of simulation is :  5.2249999999987375
# Final time of simulation is :  5.235999999998678
# Final time of simulation is :  5.246999999998619
# Final time of simulation is :  5.257999999998559
# Final time of simulation is :  5.2689999999985
# Final time of simulation is :  5.279999999998441
# [Step 480] reward=-3.302014
# Final time of simulation is :  5.290999999998381
# Final time of simulation is :  5.301999999998322
# Final time of simulation is :  5.3129999999982624
# Final time of simulation is :  5.323999999998203
# Final time of simulation is :  5.334999999998144
# Final time of simulation is :  5.345999999998084
# Final time of simulation is :  5.356999999998025
# Final time of simulation is :  5.3679999999979655
# Final time of simulation is :  5.378999999997906
# Final time of simulation is :  5.389999999997847
# Final time of simulation is :  5.400999999997787
# Final time of simulation is :  5.411999999997728
# Final time of simulation is :  5.422999999997669
# Final time of simulation is :  5.433999999997609
# Final time of simulation is :  5.44499999999755
# Final time of simulation is :  5.45599999999749
# Final time of simulation is :  5.466999999997431
# Final time of simulation is :  5.477999999997372
# Final time of simulation is :  5.488999999997312
# Final time of simulation is :  5.499999999997253
# [Step 500] reward=-6.193355
# Final time of simulation is :  5.5109999999971935
# Final time of simulation is :  5.521999999997134
# Final time of simulation is :  5.532999999997075
# Final time of simulation is :  5.543999999997015
# Final time of simulation is :  5.554999999996956
# Final time of simulation is :  5.5659999999968965
# Final time of simulation is :  5.576999999996837
# Final time of simulation is :  5.587999999996778
# Final time of simulation is :  5.598999999996718
# Final time of simulation is :  5.609999999996659
# Final time of simulation is :  5.6209999999966
# Final time of simulation is :  5.63199999999654
# Final time of simulation is :  5.642999999996481
# Final time of simulation is :  5.653999999996421
# Final time of simulation is :  5.664999999996362
# Final time of simulation is :  5.675999999996303
# Final time of simulation is :  5.686999999996243
# Final time of simulation is :  5.697999999996184
# Final time of simulation is :  5.7089999999961245
# Final time of simulation is :  5.719999999996065
# [Step 520] reward=-2.848605
# Final time of simulation is :  5.730999999996006
# Final time of simulation is :  5.741999999995946
# Final time of simulation is :  5.752999999995887
# Final time of simulation is :  5.763999999995828
# Final time of simulation is :  5.774999999995768
# Final time of simulation is :  5.785999999995709
# Final time of simulation is :  5.796999999995649
# Final time of simulation is :  5.80799999999559
# Final time of simulation is :  5.818999999995531
# Final time of simulation is :  5.829999999995471
# Final time of simulation is :  5.840999999995412
# Final time of simulation is :  5.8519999999953525
# Final time of simulation is :  5.862999999995293
# Final time of simulation is :  5.873999999995234
# Final time of simulation is :  5.884999999995174
# Final time of simulation is :  5.895999999995115
# Final time of simulation is :  5.9069999999950555
# Final time of simulation is :  5.917999999994996
# Final time of simulation is :  5.928999999994937
# Final time of simulation is :  5.939999999994877
# [Step 540] reward=-5.180493
# Final time of simulation is :  5.950999999994818
# Final time of simulation is :  5.961999999994759
# Final time of simulation is :  5.972999999994699
# Final time of simulation is :  5.98399999999464
# Final time of simulation is :  5.99499999999458
# Final time of simulation is :  6.005999999994521
# Final time of simulation is :  6.016999999994462
# Final time of simulation is :  6.027999999994402
# Final time of simulation is :  6.038999999994343
# Final time of simulation is :  6.0499999999942835
# Final time of simulation is :  6.060999999994224
# Final time of simulation is :  6.071999999994165
# Final time of simulation is :  6.082999999994105
# Final time of simulation is :  6.093999999994046
# Final time of simulation is :  6.104999999993987
# Final time of simulation is :  6.115999999993927
# Final time of simulation is :  6.126999999993868
# Final time of simulation is :  6.137999999993808
# Final time of simulation is :  6.148999999993749
# Final time of simulation is :  6.15999999999369
# [Step 560] reward=-4.339862
# Final time of simulation is :  6.17099999999363
# Final time of simulation is :  6.181999999993571
# Final time of simulation is :  6.1929999999935115
# Final time of simulation is :  6.203999999993452
# Final time of simulation is :  6.214999999993393
# Final time of simulation is :  6.225999999993333
# Final time of simulation is :  6.236999999993274
# Final time of simulation is :  6.2479999999932145
# Final time of simulation is :  6.258999999993155
# Final time of simulation is :  6.269999999993096
# Final time of simulation is :  6.280999999993036
# Final time of simulation is :  6.291999999992977
# Final time of simulation is :  6.302999999992918
# Final time of simulation is :  6.313999999992858
# Final time of simulation is :  6.324999999992799
# Final time of simulation is :  6.335999999992739
# Final time of simulation is :  6.34699999999268
# Final time of simulation is :  6.357999999992621
# Final time of simulation is :  6.368999999992561
# Final time of simulation is :  6.379999999992502
# [Step 580] reward=-3.603987
# Final time of simulation is :  6.3909999999924425
# Final time of simulation is :  6.401999999992383
# Final time of simulation is :  6.412999999992324
# Final time of simulation is :  6.423999999992264
# Final time of simulation is :  6.434999999992205
# Final time of simulation is :  6.445999999992146
# Final time of simulation is :  6.456999999992086
# Final time of simulation is :  6.467999999992027
# Final time of simulation is :  6.478999999991967
# Final time of simulation is :  6.489999999991908
# Final time of simulation is :  6.500999999991849
# Final time of simulation is :  6.511999999991789
# Final time of simulation is :  6.52299999999173
# Final time of simulation is :  6.5339999999916705
# Final time of simulation is :  6.544999999991611
# Final time of simulation is :  6.555999999991552
# Final time of simulation is :  6.566999999991492
# Final time of simulation is :  6.577999999991433
# Final time of simulation is :  6.5889999999913735
# Final time of simulation is :  6.599999999991314
# [Step 600] reward=-4.770777
# Final time of simulation is :  6.610999999991255
# Final time of simulation is :  6.621999999991195
# Final time of simulation is :  6.632999999991136
# Final time of simulation is :  6.643999999991077
# Final time of simulation is :  6.654999999991017
# Final time of simulation is :  6.665999999990958
# Final time of simulation is :  6.676999999990898
# Final time of simulation is :  6.687999999990839
# Final time of simulation is :  6.69899999999078
# Final time of simulation is :  6.70999999999072
# Final time of simulation is :  6.720999999990661
# Final time of simulation is :  6.7319999999906015
# Final time of simulation is :  6.742999999990542
# Final time of simulation is :  6.753999999990483
# Final time of simulation is :  6.764999999990423
# Final time of simulation is :  6.775999999990364
# Final time of simulation is :  6.786999999990305
# Final time of simulation is :  6.797999999990245
# Final time of simulation is :  6.808999999990186
# Final time of simulation is :  6.819999999990126
# [Step 620] reward=-3.847535
# Final time of simulation is :  6.830999999990067
# Final time of simulation is :  6.841999999990008
# Final time of simulation is :  6.852999999989948
# Final time of simulation is :  6.863999999989889
# Final time of simulation is :  6.8749999999898295
# Final time of simulation is :  6.88599999998977
# Final time of simulation is :  6.896999999989711
# Final time of simulation is :  6.907999999989651
# Final time of simulation is :  6.918999999989592
# Final time of simulation is :  6.9299999999895325
# Final time of simulation is :  6.940999999989473
# Final time of simulation is :  6.951999999989414
# Final time of simulation is :  6.962999999989354
# Final time of simulation is :  6.973999999989295
# Final time of simulation is :  6.984999999989236
# Final time of simulation is :  6.995999999989176
# Final time of simulation is :  7.006999999989117
# Final time of simulation is :  7.017999999989057
# Final time of simulation is :  7.028999999988998
# Final time of simulation is :  7.039999999988939
# [Step 640] reward=-1.463298
# Final time of simulation is :  7.050999999988879
# Final time of simulation is :  7.06199999998882
# Final time of simulation is :  7.0729999999887605
# Final time of simulation is :  7.083999999988701
# Final time of simulation is :  7.094999999988642
# Final time of simulation is :  7.105999999988582
# Final time of simulation is :  7.116999999988523
# Final time of simulation is :  7.127999999988464
# Final time of simulation is :  7.138999999988404
# Final time of simulation is :  7.149999999988345
# Final time of simulation is :  7.160999999988285
# Final time of simulation is :  7.171999999988226
# Final time of simulation is :  7.182999999988167
# Final time of simulation is :  7.193999999988107
# Final time of simulation is :  7.204999999988048
# Final time of simulation is :  7.2159999999879885
# Final time of simulation is :  7.226999999987929
# Final time of simulation is :  7.23799999998787
# Final time of simulation is :  7.24899999998781
# Final time of simulation is :  7.259999999987751
# [Step 660] reward=-5.099089
# Final time of simulation is :  7.2709999999876915
# Final time of simulation is :  7.281999999987632
# Final time of simulation is :  7.292999999987573
# Final time of simulation is :  7.303999999987513
# Final time of simulation is :  7.314999999987454
# Final time of simulation is :  7.325999999987395
# Final time of simulation is :  7.336999999987335
# Final time of simulation is :  7.347999999987276
# Final time of simulation is :  7.358999999987216
# Final time of simulation is :  7.369999999987157
# Final time of simulation is :  7.380999999987098
# Final time of simulation is :  7.391999999987038
# Final time of simulation is :  7.402999999986979
# Final time of simulation is :  7.4139999999869195
# Final time of simulation is :  7.42499999998686
# Final time of simulation is :  7.435999999986801
# Final time of simulation is :  7.446999999986741
# Final time of simulation is :  7.457999999986682
# Final time of simulation is :  7.468999999986623
# Final time of simulation is :  7.479999999986563
# [Step 680] reward=-2.052859
# Final time of simulation is :  7.490999999986504
# Final time of simulation is :  7.501999999986444
# Final time of simulation is :  7.512999999986385
# Final time of simulation is :  7.523999999986326
# Final time of simulation is :  7.534999999986266
# Final time of simulation is :  7.545999999986207
# Final time of simulation is :  7.5569999999861475
# Final time of simulation is :  7.567999999986088
# Final time of simulation is :  7.578999999986029
# Final time of simulation is :  7.589999999985969
# Final time of simulation is :  7.60099999998591
# Final time of simulation is :  7.6119999999858505
# Final time of simulation is :  7.622999999985791
# Final time of simulation is :  7.633999999985732
# Final time of simulation is :  7.644999999985672
# Final time of simulation is :  7.655999999985613
# Final time of simulation is :  7.666999999985554
# Final time of simulation is :  7.677999999985494
# Final time of simulation is :  7.688999999985435
# Final time of simulation is :  7.699999999985375
# [Step 700] reward=-3.388317
# Final time of simulation is :  7.710999999985316
# Final time of simulation is :  7.721999999985257
# Final time of simulation is :  7.732999999985197
# Final time of simulation is :  7.743999999985138
# Final time of simulation is :  7.7549999999850785
# Final time of simulation is :  7.765999999985019
# Final time of simulation is :  7.77699999998496
# Final time of simulation is :  7.7879999999849
# Final time of simulation is :  7.798999999984841
# Final time of simulation is :  7.809999999984782
# Final time of simulation is :  7.820999999984722
# Final time of simulation is :  7.831999999984663
# Final time of simulation is :  7.842999999984603
# Final time of simulation is :  7.853999999984544
# Final time of simulation is :  7.864999999984485
# Final time of simulation is :  7.875999999984425
# Final time of simulation is :  7.886999999984366
# Final time of simulation is :  7.8979999999843065
# Final time of simulation is :  7.908999999984247
# Final time of simulation is :  7.919999999984188
# [Step 720] reward=-4.247986
# Final time of simulation is :  7.930999999984128
# Final time of simulation is :  7.941999999984069
# Final time of simulation is :  7.9529999999840095
# Final time of simulation is :  7.96399999998395
# Final time of simulation is :  7.974999999983891
# Final time of simulation is :  7.985999999983831
# Final time of simulation is :  7.996999999983772
# Final time of simulation is :  8.007999999983854
# Final time of simulation is :  8.018999999983988
# Final time of simulation is :  8.029999999984122
# Final time of simulation is :  8.040999999984257
# Final time of simulation is :  8.05199999998439
# Final time of simulation is :  8.062999999984525
# Final time of simulation is :  8.07399999998466
# Final time of simulation is :  8.084999999984793
# Final time of simulation is :  8.095999999984928
# Final time of simulation is :  8.106999999985062
# Final time of simulation is :  8.117999999985196
# Final time of simulation is :  8.12899999998533
# Final time of simulation is :  8.139999999985465
# [Step 740] reward=-6.070820
# Final time of simulation is :  8.150999999985599
# Final time of simulation is :  8.161999999985733
# Final time of simulation is :  8.172999999985867
# Final time of simulation is :  8.183999999986002
# Final time of simulation is :  8.194999999986136
# Final time of simulation is :  8.20599999998627
# Final time of simulation is :  8.216999999986404
# Final time of simulation is :  8.227999999986539
# Final time of simulation is :  8.238999999986673
# Final time of simulation is :  8.249999999986807
# Final time of simulation is :  8.260999999986941
# Final time of simulation is :  8.271999999987075
# Final time of simulation is :  8.28299999998721
# Final time of simulation is :  8.293999999987344
# Final time of simulation is :  8.304999999987478
# Final time of simulation is :  8.315999999987612
# Final time of simulation is :  8.326999999987747
# Final time of simulation is :  8.33799999998788
# Final time of simulation is :  8.348999999988015
# Final time of simulation is :  8.35999999998815
# [Step 760] reward=-3.385724
# Final time of simulation is :  8.370999999988284
# Final time of simulation is :  8.381999999988418
# Final time of simulation is :  8.392999999988552
# Final time of simulation is :  8.403999999988686
# Final time of simulation is :  8.41499999998882
# Final time of simulation is :  8.425999999988955
# Final time of simulation is :  8.436999999989089
# Final time of simulation is :  8.447999999989223
# Final time of simulation is :  8.458999999989357
# Final time of simulation is :  8.469999999989492
# Final time of simulation is :  8.480999999989626
# Final time of simulation is :  8.49199999998976
# Final time of simulation is :  8.502999999989894
# Final time of simulation is :  8.513999999990029
# Final time of simulation is :  8.524999999990163
# Final time of simulation is :  8.535999999990297
# Final time of simulation is :  8.546999999990431
# Final time of simulation is :  8.557999999990566
# Final time of simulation is :  8.5689999999907
# Final time of simulation is :  8.579999999990834
# [Step 780] reward=-3.390013
# Final time of simulation is :  8.590999999990968
# Final time of simulation is :  8.601999999991103
# Final time of simulation is :  8.612999999991237
# Final time of simulation is :  8.623999999991371
# Final time of simulation is :  8.634999999991505
# Final time of simulation is :  8.64599999999164
# Final time of simulation is :  8.656999999991774
# Final time of simulation is :  8.667999999991908
# Final time of simulation is :  8.678999999992042
# Final time of simulation is :  8.689999999992176
# Final time of simulation is :  8.70099999999231
# Final time of simulation is :  8.711999999992445
# Final time of simulation is :  8.72299999999258
# Final time of simulation is :  8.733999999992713
# Final time of simulation is :  8.744999999992848
# Final time of simulation is :  8.755999999992982
# Final time of simulation is :  8.766999999993116
# Final time of simulation is :  8.77799999999325
# Final time of simulation is :  8.788999999993385
# Final time of simulation is :  8.799999999993519
# [Step 800] reward=-3.327526
# Final time of simulation is :  8.810999999993653
# Final time of simulation is :  8.821999999993787
# Final time of simulation is :  8.832999999993921
# Final time of simulation is :  8.843999999994056
# Final time of simulation is :  8.85499999999419
# Final time of simulation is :  8.865999999994324
# Final time of simulation is :  8.876999999994458
# Final time of simulation is :  8.887999999994593
# Final time of simulation is :  8.898999999994727
# Final time of simulation is :  8.909999999994861
# Final time of simulation is :  8.920999999994995
# Final time of simulation is :  8.93199999999513
# Final time of simulation is :  8.942999999995264
# Final time of simulation is :  8.953999999995398
# Final time of simulation is :  8.964999999995532
# Final time of simulation is :  8.975999999995667
# Final time of simulation is :  8.9869999999958
# Final time of simulation is :  8.997999999995935
# Final time of simulation is :  9.00899999999607
# Final time of simulation is :  9.019999999996203
# [Step 820] reward=-3.909434
# Final time of simulation is :  9.030999999996338
# Final time of simulation is :  9.041999999996472
# Final time of simulation is :  9.052999999996606
# Final time of simulation is :  9.06399999999674
# Final time of simulation is :  9.074999999996875
# Final time of simulation is :  9.085999999997009
# Final time of simulation is :  9.096999999997143
# Final time of simulation is :  9.107999999997277
# Final time of simulation is :  9.118999999997412
# Final time of simulation is :  9.129999999997546
# Final time of simulation is :  9.14099999999768
# Final time of simulation is :  9.151999999997814
# Final time of simulation is :  9.162999999997949
# Final time of simulation is :  9.173999999998083
# Final time of simulation is :  9.184999999998217
# Final time of simulation is :  9.195999999998351
# Final time of simulation is :  9.206999999998486
# Final time of simulation is :  9.21799999999862
# Final time of simulation is :  9.228999999998754
# Final time of simulation is :  9.239999999998888
# [Step 840] reward=-1.722319
# Final time of simulation is :  9.250999999999022
# Final time of simulation is :  9.261999999999157
# Final time of simulation is :  9.272999999999291
# Final time of simulation is :  9.283999999999425
# Final time of simulation is :  9.29499999999956
# Final time of simulation is :  9.305999999999694
# Final time of simulation is :  9.316999999999828
# Final time of simulation is :  9.327999999999962
# Final time of simulation is :  9.339000000000096
# Final time of simulation is :  9.35000000000023
# Final time of simulation is :  9.361000000000365
# Final time of simulation is :  9.372000000000499
# Final time of simulation is :  9.383000000000633
# Final time of simulation is :  9.394000000000768
# Final time of simulation is :  9.405000000000902
# Final time of simulation is :  9.416000000001036
# Final time of simulation is :  9.42700000000117
# Final time of simulation is :  9.438000000001304
# Final time of simulation is :  9.449000000001439
# Final time of simulation is :  9.460000000001573
# [Step 860] reward=-3.786126
# Final time of simulation is :  9.471000000001707
# Final time of simulation is :  9.482000000001841
# Final time of simulation is :  9.493000000001976
# Final time of simulation is :  9.50400000000211
# Final time of simulation is :  9.515000000002244
# Final time of simulation is :  9.526000000002378
# Final time of simulation is :  9.537000000002513
# Final time of simulation is :  9.548000000002647
# Final time of simulation is :  9.559000000002781
# Final time of simulation is :  9.570000000002915
# Final time of simulation is :  9.58100000000305
# Final time of simulation is :  9.592000000003184
# Final time of simulation is :  9.603000000003318
# Final time of simulation is :  9.614000000003452
# Final time of simulation is :  9.625000000003586
# Final time of simulation is :  9.63600000000372
# Final time of simulation is :  9.647000000003855
# Final time of simulation is :  9.65800000000399
# Final time of simulation is :  9.669000000004123
# Final time of simulation is :  9.680000000004258
# [Step 880] reward=-2.601007
# Final time of simulation is :  9.691000000004392
# Final time of simulation is :  9.702000000004526
# Final time of simulation is :  9.71300000000466
# Final time of simulation is :  9.724000000004795
# Final time of simulation is :  9.735000000004929
# Final time of simulation is :  9.746000000005063
# Final time of simulation is :  9.757000000005197
# Final time of simulation is :  9.768000000005332
# Final time of simulation is :  9.779000000005466
# Final time of simulation is :  9.7900000000056
# Final time of simulation is :  9.801000000005734
# Final time of simulation is :  9.812000000005868
# Final time of simulation is :  9.823000000006003
# Final time of simulation is :  9.834000000006137
# Final time of simulation is :  9.845000000006271
# Final time of simulation is :  9.856000000006405
# Final time of simulation is :  9.86700000000654
# Final time of simulation is :  9.878000000006674
# Final time of simulation is :  9.889000000006808
# Final time of simulation is :  9.900000000006942
# [Step 900] reward=-2.358663
# Final time of simulation is :  9.911000000007077
# Final time of simulation is :  9.92200000000721
# Final time of simulation is :  9.933000000007345
# Final time of simulation is :  9.94400000000748
# Final time of simulation is :  9.955000000007614
# Final time of simulation is :  9.966000000007748
# Final time of simulation is :  9.977000000007882
# Final time of simulation is :  9.988000000008016
# Final time of simulation is :  9.99900000000815
# Final time of simulation is :  10.010000000008285
# Final time of simulation is :  10.021000000008419
# Final time of simulation is :  10.032000000008553
# Final time of simulation is :  10.043000000008687
# Final time of simulation is :  10.054000000008822
# Final time of simulation is :  10.065000000008956
# Final time of simulation is :  10.07600000000909
# Final time of simulation is :  10.087000000009224
# Final time of simulation is :  10.098000000009359
# Final time of simulation is :  10.109000000009493
# Final time of simulation is :  10.120000000009627
# [Step 920] reward=-4.409397
# Final time of simulation is :  10.131000000009761
# Final time of simulation is :  10.142000000009896
# Final time of simulation is :  10.15300000001003
# Final time of simulation is :  10.164000000010164
# Final time of simulation is :  10.175000000010298
# Final time of simulation is :  10.186000000010432
# Final time of simulation is :  10.197000000010567
# Final time of simulation is :  10.208000000010701
# Final time of simulation is :  10.219000000010835
# Final time of simulation is :  10.23000000001097
# Final time of simulation is :  10.241000000011104
# Final time of simulation is :  10.252000000011238
# Final time of simulation is :  10.263000000011372
# Final time of simulation is :  10.274000000011506
# Final time of simulation is :  10.28500000001164
# Final time of simulation is :  10.296000000011775
# Final time of simulation is :  10.307000000011909
# Final time of simulation is :  10.318000000012043
# Final time of simulation is :  10.329000000012178
# Final time of simulation is :  10.340000000012312
# [Step 940] reward=-4.379489
# Final time of simulation is :  10.351000000012446
# Final time of simulation is :  10.36200000001258
# Final time of simulation is :  10.373000000012714
# Final time of simulation is :  10.384000000012849
# Final time of simulation is :  10.395000000012983
# Final time of simulation is :  10.406000000013117
# ...
# [Step 1740] reward=-5.872535
# Final time of simulation is :  19.151000000008906
# Final time of simulation is :  19.162000000008653
# Final time of simulation is :  19.1730000000084
# Final time of simulation is :  19.184000000008147
# Final time of simulation is :  19.195000000007894
# Final time of simulation is :  19.20600000000764
# Final time of simulation is :  19.21700000000739
# Final time of simulation is :  19.228000000007135
# Final time of simulation is :  19.239000000006882
# Final time of simulation is :  19.25000000000663
# Final time of simulation is :  19.261000000006376
# Final time of simulation is :  19.272000000006123
# Final time of simulation is :  19.28300000000587
# Final time of simulation is :  19.294000000005617
# Final time of simulation is :  19.305000000005364
# Final time of simulation is :  19.31600000000511
# Final time of simulation is :  19.32700000000486
# Final time of simulation is :  19.338000000004605
# Final time of simulation is :  19.349000000004352
# Final time of simulation is :  19.3600000000041
# [Step 1760] reward=-4.179141
# Final time of simulation is :  19.371000000003846
# Final time of simulation is :  19.382000000003593
# Final time of simulation is :  19.39300000000334
# Final time of simulation is :  19.404000000003087
# Final time of simulation is :  19.415000000002834
# Final time of simulation is :  19.42600000000258
# Final time of simulation is :  19.437000000002328
# Final time of simulation is :  19.448000000002075
# Final time of simulation is :  19.459000000001822
# Final time of simulation is :  19.47000000000157
# Final time of simulation is :  19.481000000001316
# Final time of simulation is :  19.492000000001063
# Final time of simulation is :  19.50300000000081
# Final time of simulation is :  19.514000000000557
# Final time of simulation is :  19.525000000000304
# Final time of simulation is :  19.53600000000005
# Final time of simulation is :  19.546999999999798
# Final time of simulation is :  19.557999999999545
# Final time of simulation is :  19.568999999999292
# Final time of simulation is :  19.57999999999904
# [Step 1780] reward=-1.911439
# Final time of simulation is :  19.590999999998786
# Final time of simulation is :  19.601999999998533
# Final time of simulation is :  19.61299999999828
# Final time of simulation is :  19.623999999998027
# Final time of simulation is :  19.634999999997774
# Final time of simulation is :  19.64599999999752
# Final time of simulation is :  19.656999999997268
# Final time of simulation is :  19.667999999997015
# Final time of simulation is :  19.678999999996762
# Final time of simulation is :  19.68999999999651
# Final time of simulation is :  19.700999999996256
# Final time of simulation is :  19.711999999996003
# Final time of simulation is :  19.72299999999575
# Final time of simulation is :  19.733999999995497
# Final time of simulation is :  19.744999999995244
# Final time of simulation is :  19.75599999999499
# Final time of simulation is :  19.766999999994738
# Final time of simulation is :  19.777999999994485
# Final time of simulation is :  19.788999999994232
# Final time of simulation is :  19.79999999999398
# [Step 1800] reward=-6.004155
# Final time of simulation is :  19.810999999993726
# Final time of simulation is :  19.821999999993473
# Final time of simulation is :  19.83299999999322
# Final time of simulation is :  19.843999999992967
# Final time of simulation is :  19.854999999992714
# Final time of simulation is :  19.86599999999246
# Final time of simulation is :  19.876999999992208
# Final time of simulation is :  19.887999999991955
# Final time of simulation is :  19.8989999999917
# Final time of simulation is :  19.90999999999145
# Final time of simulation is :  19.920999999991196
# Final time of simulation is :  19.931999999990943
# Final time of simulation is :  19.94299999999069
# Final time of simulation is :  19.953999999990437
# Final time of simulation is :  19.964999999990184
# Final time of simulation is :  19.97599999998993
# Final time of simulation is :  19.986999999989678
# Final time of simulation is :  19.997999999989425
# Final time of simulation is :  20.00899999998917
# Final time of simulation is :  20.01999999998892
# [Step 1820] reward=-4.552441
# Final time of simulation is :  20.030999999988666
# Final time of simulation is :  20.041999999988413
# Final time of simulation is :  20.05299999998816
# Final time of simulation is :  20.063999999987907
# Final time of simulation is :  20.074999999987654
# Final time of simulation is :  20.0859999999874
# Final time of simulation is :  20.096999999987148
# Final time of simulation is :  20.107999999986895
# Final time of simulation is :  20.11899999998664
# Final time of simulation is :  20.12999999998639
# Final time of simulation is :  20.140999999986136
# Final time of simulation is :  20.151999999985883
# Final time of simulation is :  20.16299999998563
# Final time of simulation is :  20.173999999985377
# Final time of simulation is :  20.184999999985124
# Final time of simulation is :  20.19599999998487
# Final time of simulation is :  20.206999999984617
# Final time of simulation is :  20.217999999984364
# Final time of simulation is :  20.22899999998411
# Final time of simulation is :  20.23999999998386
# [Step 1840] reward=-4.958499
# Final time of simulation is :  20.250999999983605
# Final time of simulation is :  20.261999999983352
# Final time of simulation is :  20.2729999999831
# Final time of simulation is :  20.283999999982846
# Final time of simulation is :  20.294999999982593
# Final time of simulation is :  20.30599999998234
# Final time of simulation is :  20.316999999982087
# Final time of simulation is :  20.327999999981834
# Final time of simulation is :  20.33899999998158
# Final time of simulation is :  20.34999999998133
# Final time of simulation is :  20.360999999981075
# Final time of simulation is :  20.371999999980822
# Final time of simulation is :  20.38299999998057
# Final time of simulation is :  20.393999999980316
# Final time of simulation is :  20.404999999980063
# Final time of simulation is :  20.41599999997981
# Final time of simulation is :  20.426999999979557
# Final time of simulation is :  20.437999999979304
# Final time of simulation is :  20.44899999997905
# Final time of simulation is :  20.4599999999788
# [Step 1860] reward=-4.970709
# Final time of simulation is :  20.470999999978545
# Final time of simulation is :  20.481999999978292
# Final time of simulation is :  20.49299999997804
# Final time of simulation is :  20.503999999977786
# Final time of simulation is :  20.514999999977533
# Final time of simulation is :  20.52599999997728
# Final time of simulation is :  20.536999999977027
# Final time of simulation is :  20.547999999976774
# Final time of simulation is :  20.55899999997652
# Final time of simulation is :  20.569999999976268
# Final time of simulation is :  20.580999999976015
# Final time of simulation is :  20.591999999975762
# Final time of simulation is :  20.60299999997551
# Final time of simulation is :  20.613999999975256
# Final time of simulation is :  20.624999999975003
# Final time of simulation is :  20.63599999997475
# Final time of simulation is :  20.646999999974497
# Final time of simulation is :  20.657999999974244
# Final time of simulation is :  20.66899999997399
# Final time of simulation is :  20.679999999973738
# [Step 1880] reward=-2.939842
# Final time of simulation is :  20.690999999973485
# Final time of simulation is :  20.701999999973232
# Final time of simulation is :  20.71299999997298
# Final time of simulation is :  20.723999999972726
# Final time of simulation is :  20.734999999972473
# Final time of simulation is :  20.74599999997222
# Final time of simulation is :  20.756999999971967
# Final time of simulation is :  20.767999999971714
# Final time of simulation is :  20.77899999997146
# Final time of simulation is :  20.789999999971208
# Final time of simulation is :  20.800999999970955
# Final time of simulation is :  20.811999999970702
# Final time of simulation is :  20.82299999997045
# Final time of simulation is :  20.833999999970196
# Final time of simulation is :  20.844999999969943
# Final time of simulation is :  20.85599999996969
# Final time of simulation is :  20.866999999969437
# Final time of simulation is :  20.877999999969184
# Final time of simulation is :  20.88899999996893
# Final time of simulation is :  20.899999999968678
# [Step 1900] reward=-3.745117
# Final time of simulation is :  20.910999999968425
# Final time of simulation is :  20.921999999968172
# Final time of simulation is :  20.93299999996792
# Final time of simulation is :  20.943999999967666
# Final time of simulation is :  20.954999999967413
# Final time of simulation is :  20.96599999996716
# Final time of simulation is :  20.976999999966907
# Final time of simulation is :  20.987999999966654
# Final time of simulation is :  20.9989999999664
# Final time of simulation is :  21.009999999966148
# Final time of simulation is :  21.020999999965895
# Final time of simulation is :  21.03199999996564
# Final time of simulation is :  21.04299999996539
# Final time of simulation is :  21.053999999965136
# Final time of simulation is :  21.064999999964883
# Final time of simulation is :  21.07599999996463
# Final time of simulation is :  21.086999999964377
# Final time of simulation is :  21.097999999964124
# Final time of simulation is :  21.10899999996387
# Final time of simulation is :  21.119999999963618
# [Step 1920] reward=-6.110265
# Final time of simulation is :  21.130999999963365
# Final time of simulation is :  21.14199999996311
# Final time of simulation is :  21.15299999996286
# Final time of simulation is :  21.163999999962606
# Final time of simulation is :  21.174999999962353
# Final time of simulation is :  21.1859999999621
# Final time of simulation is :  21.196999999961847
# Final time of simulation is :  21.207999999961594
# Final time of simulation is :  21.21899999996134
# Final time of simulation is :  21.229999999961088
# Final time of simulation is :  21.240999999960835
# Final time of simulation is :  21.25199999996058
# Final time of simulation is :  21.26299999996033
# Final time of simulation is :  21.273999999960076
# Final time of simulation is :  21.284999999959823
# Final time of simulation is :  21.29599999995957
# Final time of simulation is :  21.306999999959316
# Final time of simulation is :  21.317999999959063
# Final time of simulation is :  21.32899999995881
# Final time of simulation is :  21.339999999958557
# [Step 1940] reward=-4.276245
# Final time of simulation is :  21.350999999958304
# Final time of simulation is :  21.36199999995805
# Final time of simulation is :  21.3729999999578
# Final time of simulation is :  21.383999999957545
# Final time of simulation is :  21.394999999957292
# Final time of simulation is :  21.40599999995704
# Final time of simulation is :  21.416999999956786
# Final time of simulation is :  21.427999999956533
# Final time of simulation is :  21.43899999995628
# Final time of simulation is :  21.449999999956027
# Final time of simulation is :  21.460999999955774
# Final time of simulation is :  21.47199999995552
# Final time of simulation is :  21.48299999995527
# Final time of simulation is :  21.493999999955015
# Final time of simulation is :  21.504999999954762
# Final time of simulation is :  21.51599999995451
# Final time of simulation is :  21.526999999954256
# Final time of simulation is :  21.537999999954003
# Final time of simulation is :  21.54899999995375
# Final time of simulation is :  21.559999999953497
# [Step 1960] reward=-4.565202
# Final time of simulation is :  21.570999999953244
# Final time of simulation is :  21.58199999995299
# Final time of simulation is :  21.592999999952738
# Final time of simulation is :  21.603999999952485
# Final time of simulation is :  21.614999999952232
# Final time of simulation is :  21.62599999995198
# Final time of simulation is :  21.636999999951726
# Final time of simulation is :  21.647999999951473
# Final time of simulation is :  21.65899999995122
# Final time of simulation is :  21.669999999950967
# Final time of simulation is :  21.680999999950714
# Final time of simulation is :  21.69199999995046
# Final time of simulation is :  21.702999999950208
# Final time of simulation is :  21.713999999949955
# Final time of simulation is :  21.724999999949702
# Final time of simulation is :  21.73599999994945
# Final time of simulation is :  21.746999999949196
# Final time of simulation is :  21.757999999948943
# Final time of simulation is :  21.76899999994869
# Final time of simulation is :  21.779999999948437
# [Step 1980] reward=-4.474232
# Final time of simulation is :  21.790999999948184
# Final time of simulation is :  21.80199999994793
# Final time of simulation is :  21.812999999947678
# Final time of simulation is :  21.823999999947425
# Final time of simulation is :  21.834999999947172
# Final time of simulation is :  21.84599999994692
# Final time of simulation is :  21.856999999946666
# Final time of simulation is :  21.867999999946413
# Final time of simulation is :  21.87899999994616
# Final time of simulation is :  21.889999999945907
# Final time of simulation is :  21.900999999945654
# Final time of simulation is :  21.9119999999454
# Final time of simulation is :  21.922999999945148
# Final time of simulation is :  21.933999999944895
# Final time of simulation is :  21.944999999944642
# Final time of simulation is :  21.95599999994439
# Final time of simulation is :  21.966999999944136
# Final time of simulation is :  21.977999999943883
# Final time of simulation is :  21.98899999994363
# Final time of simulation is :  21.999999999943377
# [Step 2000] reward=-5.505533
# Final time of simulation is :  22.010999999943124
# Final time of simulation is :  22.02199999994287
# Final time of simulation is :  22.032999999942618
# Final time of simulation is :  22.043999999942365
# Final time of simulation is :  22.054999999942112
# Final time of simulation is :  22.06599999994186
# Final time of simulation is :  22.076999999941606
# Final time of simulation is :  22.087999999941353
# Final time of simulation is :  22.0989999999411
# Final time of simulation is :  22.109999999940847
# Final time of simulation is :  22.120999999940594
# Final time of simulation is :  22.13199999994034
# Final time of simulation is :  22.142999999940088
# Final time of simulation is :  22.153999999939835
# Final time of simulation is :  22.16499999993958
# Final time of simulation is :  22.17599999993933
# Final time of simulation is :  22.186999999939076
# Final time of simulation is :  22.197999999938823
# Final time of simulation is :  22.20899999993857
# Final time of simulation is :  22.219999999938317
# [Step 2020] reward=-4.400313
# Final time of simulation is :  22.230999999938064
# Final time of simulation is :  22.24199999993781
# Final time of simulation is :  22.252999999937558
# Final time of simulation is :  22.263999999937305
# Final time of simulation is :  22.27499999993705
# Final time of simulation is :  22.2859999999368
# Final time of simulation is :  22.296999999936546
# Final time of simulation is :  22.307999999936293
# Final time of simulation is :  22.31899999993604
# Final time of simulation is :  22.329999999935787
# Final time of simulation is :  22.340999999935534
# Final time of simulation is :  22.35199999993528
# Final time of simulation is :  22.362999999935028
# Final time of simulation is :  22.373999999934775
# Final time of simulation is :  22.38499999993452
# Final time of simulation is :  22.39599999993427
# Final time of simulation is :  22.406999999934015
# Final time of simulation is :  22.417999999933762
# Final time of simulation is :  22.42899999993351
# Final time of simulation is :  22.439999999933256
# [Step 2040] reward=-5.085090
# Final time of simulation is :  22.450999999933003
# Final time of simulation is :  22.46199999993275
# Final time of simulation is :  22.472999999932497
# Final time of simulation is :  22.483999999932244
# Final time of simulation is :  22.49499999993199
# Final time of simulation is :  22.50599999993174
# Final time of simulation is :  22.516999999931485
# Final time of simulation is :  22.527999999931232
# -----------------------------
# | time/              |      |
# |    fps             | 152  |
# |    iterations      | 1    |
# |    time_elapsed    | 13   |
# |    total_timesteps | 2048 |
# -----------------------------

# %%
import os

save_dir = os.path.join("Training", "Saved_Models")
os.makedirs(save_dir, exist_ok=True)        # create folders the first time

model_path = os.path.join(save_dir, "PPO_Snake_Model")
model.save(model_path)
print(f"Training finished! Model saved to {model_path}")

# %% [markdown]
# load and run trained models

# %%
# Recreate the environment (since it was closed in Cell 14)


# Load the trained model
model_path = os.path.join("Training", "Saved_Models", "PPO_Snake_Model_3")
model = PPO.load(model_path, env=env)
print(f"Model loaded from {model_path}")
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Model loaded from Training/Saved_Models/PPO_Snake_Model_3

# %%
# Create environment with fixed wavelength (action space size 6)
# To allow modifiable wavelength (action space size 7), use VariableWavelengthContinuumSnakeEnv.

# Customize the observation/state space by editing this list of keys.
# Set to None to fall back to the default keys defined in BaseContinuumSnakeEnv.
custom_obs_keys = [
    "position",
    "velocity",
    "curvature",
]

env = FixedWavelengthContinuumSnakeEnv(
    fixed_wavelength=1.0,
    obs_keys=custom_obs_keys,
    
)
# Verify action space is now size 6
print(f"Action space shape: {env.action_space.shape}")
print(f"Fixed wavelength: {env.fixed_wavelength}")
print(f"Observation space shape: {env.observation_space.shape}")
print(f"Observation keys: {env.obs_keys}")

env.period = 1
env.ratio_time = 0.01
env.rut_ratio = 0.001

# %%
# Reset the environment
obs, _ = env.reset()

# %%
# Run a few steps using the trained model
num_steps = 5000  # Change this to run more or fewer steps
print(f"\nRunning {num_steps} steps with trained model...")
print("=" * 70)

import io, contextlib

total_reward = 0.0
for i in range(num_steps):
    # Get action from the trained model (deterministic=True for consistent results)
    action, _states = model.predict(obs, deterministic=True)
    # action = np.array([3.4e-3, 3.3e-3, 4.2e-3, 2.6e-3, 3.6e-3, 3.5e-3], dtype=np.float32)
    
    
    # Step the environment
    with contextlib.redirect_stdout(io.StringIO()):
        obs, reward, terminated, truncated, info = env.step(action)
    
    # Accumulate reward
    total_reward += reward
    
    # Print step information (including action)
    action_str = np.array2string(action, precision=6, suppress_small=True)
    status_line = (f"Step {i+1}/{num_steps} | "
                   f"Time: {info['current_time']:.2f}s | "
                   f"Forward: {info['forward_speed']:.4f} m/s | "
                   f"Lateral: {info['lateral_speed']:.4f} m/s | "
                   f"Reward: {reward:.4f} | "
                   f"Pos: [{info['position'][0]:.3f}, {info['position'][1]:.3f}, {info['position'][2]:.3f}] | "
                   f"Action: {action_str}")
    print(status_line)

    # Check if episode ended
    if terminated or truncated:
        print(f"Episode ended at step {i+1}")
        obs, _ = env.reset()
        print("Environment reset for next episode")

# Print summary after loop completes
print(f"\nTotal reward over {num_steps} steps: {total_reward:.4f}")
print(f"Average reward per step: {total_reward/num_steps:.4f}")
# Out:
# Running 5000 steps with trained model...
# ======================================================================
# Step 1/5000 | Time: 5.51s | Forward: 0.1447 m/s | Lateral: 0.0000 m/s | Reward: -3.2300 | Pos: [-0.201, 0.012, 0.343] | Action: [ 0.353594  1.        1.       -1.       -0.156674  0.53576 ]
# Step 2/5000 | Time: 5.52s | Forward: 0.1177 m/s | Lateral: 0.0000 m/s | Reward: -1.9792 | Pos: [-0.201, 0.012, 0.342] | Action: [ 1.       -1.        1.        0.248665 -1.        1.      ]
# Step 3/5000 | Time: 5.53s | Forward: 0.1751 m/s | Lateral: 0.0000 m/s | Reward: -1.6124 | Pos: [-0.201, 0.014, 0.340] | Action: [-0.742541  0.471178  1.       -1.       -1.        1.      ]
# Step 4/5000 | Time: 5.54s | Forward: 0.2305 m/s | Lateral: 0.0000 m/s | Reward: -2.3595 | Pos: [-0.202, 0.016, 0.339] | Action: [-1.       -0.097086  1.       -1.       -1.        1.      ]
# Step 5/5000 | Time: 5.55s | Forward: 0.2609 m/s | Lateral: 0.0000 m/s | Reward: -1.2446 | Pos: [-0.202, 0.018, 0.338] | Action: [-0.603447 -1.        0.782029  1.       -1.        1.      ]
# Step 6/5000 | Time: 5.57s | Forward: 0.1945 m/s | Lateral: 0.0000 m/s | Reward: -2.0077 | Pos: [-0.202, 0.020, 0.336] | Action: [-0.012944  1.        1.        1.       -1.        1.      ]
# Step 7/5000 | Time: 5.58s | Forward: 0.1344 m/s | Lateral: 0.0000 m/s | Reward: -1.7675 | Pos: [-0.202, 0.020, 0.335] | Action: [ 1.      1.      1.      1.     -0.3307  1.    ]
# Step 8/5000 | Time: 5.59s | Forward: 0.1467 m/s | Lateral: 0.0000 m/s | Reward: -2.1357 | Pos: [-0.202, 0.020, 0.333] | Action: [ 1.       -0.87648   0.046181  1.       -0.966984  1.      ]
# Step 9/5000 | Time: 5.60s | Forward: 0.2196 m/s | Lateral: 0.0000 m/s | Reward: -2.1423 | Pos: [-0.202, 0.018, 0.332] | Action: [-0.196794 -1.       -1.        1.       -1.       -1.      ]
# Step 10/5000 | Time: 5.61s | Forward: 0.3134 m/s | Lateral: 0.0000 m/s | Reward: -3.5429 | Pos: [-0.202, 0.015, 0.331] | Action: [ 0.266138  1.        0.128615 -1.        1.       -1.      ]
# Step 11/5000 | Time: 5.62s | Forward: 0.4000 m/s | Lateral: 0.0000 m/s | Reward: -2.7498 | Pos: [-0.202, 0.010, 0.329] | Action: [ 1.       -0.032443 -1.        1.        1.        1.      ]
# Step 12/5000 | Time: 5.63s | Forward: 0.4137 m/s | Lateral: 0.0000 m/s | Reward: -1.1027 | Pos: [-0.203, 0.006, 0.328] | Action: [-1.  1.  1. -1.  1.  1.]
# Step 13/5000 | Time: 5.64s | Forward: 0.3252 m/s | Lateral: 0.0000 m/s | Reward: -1.1850 | Pos: [-0.203, 0.003, 0.327] | Action: [-1.      -0.43275  1.      -1.       1.       1.     ]
# Step 14/5000 | Time: 5.65s | Forward: 0.2518 m/s | Lateral: 0.0000 m/s | Reward: -2.0034 | Pos: [-0.204, -0.000, 0.327] | Action: [-1.        1.        1.       -0.903647  0.180806  0.708206]
# Step 15/5000 | Time: 5.66s | Forward: 0.1576 m/s | Lateral: 0.0000 m/s | Reward: -4.8147 | Pos: [-0.204, -0.001, 0.326] | Action: [ 1.       -0.251336 -1.        0.214714 -0.770621 -0.242744]
# Step 16/5000 | Time: 5.68s | Forward: 0.2283 m/s | Lateral: 0.0000 m/s | Reward: -3.8267 | Pos: [-0.205, 0.001, 0.324] | Action: [-1.        0.159795 -0.374241  1.       -0.664667 -1.      ]
# Step 17/5000 | Time: 5.69s | Forward: 0.5703 m/s | Lateral: 0.0000 m/s | Reward: -4.5021 | Pos: [-0.206, 0.007, 0.323] | Action: [ 1.        0.147539  0.456488 -0.158011  1.       -0.456889]
# Step 18/5000 | Time: 5.70s | Forward: 0.6132 m/s | Lateral: 0.0000 m/s | Reward: -2.4142 | Pos: [-0.206, 0.013, 0.321] | Action: [0.390548 0.87586  0.807454 1.       0.704418 0.971282]
# Step 19/5000 | Time: 5.71s | Forward: 0.5561 m/s | Lateral: 0.0000 m/s | Reward: -1.4595 | Pos: [-0.206, 0.019, 0.319] | Action: [ 0.444113 -1.        1.       -0.779831 -1.       -1.      ]
# Step 20/5000 | Time: 5.72s | Forward: 0.4614 m/s | Lateral: 0.0000 m/s | Reward: -1.1245 | Pos: [-0.207, 0.024, 0.317] | Action: [-1.       -0.763417  0.925434 -1.       -1.       -1.      ]
# Step 21/5000 | Time: 5.73s | Forward: 0.3634 m/s | Lateral: 0.0000 m/s | Reward: -5.1838 | Pos: [-0.207, 0.027, 0.315] | Action: [-0.310846 -0.711973  0.044678 -1.       -0.097963  0.408971]
# Step 22/5000 | Time: 5.74s | Forward: 0.2730 m/s | Lateral: 0.0000 m/s | Reward: -2.3979 | Pos: [-0.207, 0.029, 0.314] | Action: [ 0.513474  1.        1.       -1.        1.        1.      ]
# Step 23/5000 | Time: 5.75s | Forward: 0.2007 m/s | Lateral: 0.0000 m/s | Reward: -0.9893 | Pos: [-0.208, 0.031, 0.312] | Action: [ 1.        1.        0.937256  1.       -0.820979  1.      ]
# Step 24/5000 | Time: 5.76s | Forward: 0.1711 m/s | Lateral: 0.0000 m/s | Reward: -1.6675 | Pos: [-0.208, 0.031, 0.310] | Action: [-1.       0.67424  1.      -1.      -1.       0.39691]
# Step 25/5000 | Time: 5.77s | Forward: 0.2039 m/s | Lateral: 0.0000 m/s | Reward: -2.7353 | Pos: [-0.208, 0.029, 0.308] | Action: [-1.       -0.179648 -1.        1.       -0.726055 -1.      ]
# Step 26/5000 | Time: 5.79s | Forward: 0.2777 m/s | Lateral: 0.0000 m/s | Reward: -2.0048 | Pos: [-0.209, 0.027, 0.306] | Action: [ 1.        0.509777 -1.       -1.        1.       -1.      ]
# Step 27/5000 | Time: 5.80s | Forward: 0.3686 m/s | Lateral: 0.0000 m/s | Reward: -3.8326 | Pos: [-0.209, 0.023, 0.304] | Action: [ 1.       -0.259646 -0.17701  -0.540993  1.       -0.657912]
# Step 28/5000 | Time: 5.81s | Forward: 0.3736 m/s | Lateral: 0.0000 m/s | Reward: -3.9329 | Pos: [-0.210, 0.020, 0.303] | Action: [-0.987914 -1.        0.285287 -0.026664 -1.        1.      ]
# Step 29/5000 | Time: 5.82s | Forward: 0.3893 m/s | Lateral: 0.0000 m/s | Reward: -4.2681 | Pos: [-0.211, 0.016, 0.301] | Action: [ 0.529353 -1.       -0.204435  0.987823  0.812867  0.405005]
# Step 30/5000 | Time: 5.83s | Forward: 0.4844 m/s | Lateral: 0.0000 m/s | Reward: -4.0734 | Pos: [-0.211, 0.010, 0.300] | Action: [-0.366868 -0.073678 -1.       -1.        1.        0.600414]
# Step 31/5000 | Time: 5.84s | Forward: 0.4430 m/s | Lateral: 0.0000 m/s | Reward: -2.8536 | Pos: [-0.212, 0.006, 0.300] | Action: [ 1.       -0.995275  1.       -1.       -0.092627  0.885663]
# Step 32/5000 | Time: 5.85s | Forward: 0.2020 m/s | Lateral: 0.0000 m/s | Reward: -1.3185 | Pos: [-0.213, 0.004, 0.299] | Action: [-1.       -1.        1.       -0.874899 -1.        1.      ]
# Step 33/5000 | Time: 5.86s | Forward: 0.1104 m/s | Lateral: 0.0000 m/s | Reward: -2.7558 | Pos: [-0.213, 0.005, 0.298] | Action: [ 0.188397 -1.        1.       -0.439632 -1.        1.      ]
# Step 34/5000 | Time: 5.87s | Forward: 0.2889 m/s | Lateral: 0.0000 m/s | Reward: -3.2529 | Pos: [-0.214, 0.008, 0.299] | Action: [-1.        0.563344  1.        0.935171  0.089012  1.      ]
# Step 35/5000 | Time: 5.88s | Forward: 0.3150 m/s | Lateral: 0.0000 m/s | Reward: -3.5056 | Pos: [-0.214, 0.011, 0.299] | Action: [-1.       -0.175928  1.       -1.        1.        0.289515]
# Step 36/5000 | Time: 5.90s | Forward: 0.2964 m/s | Lateral: 0.0000 m/s | Reward: -1.3832 | Pos: [-0.215, 0.014, 0.299] | Action: [ 0.998226 -1.       -0.978426  0.980059 -1.       -1.      ]
# Step 37/5000 | Time: 5.91s | Forward: 0.2061 m/s | Lateral: 0.0000 m/s | Reward: -2.9272 | Pos: [-0.215, 0.016, 0.300] | Action: [ 0.251335 -1.       -1.        0.160097 -1.       -0.717767]
# Step 38/5000 | Time: 5.92s | Forward: 0.2332 m/s | Lateral: 0.0000 m/s | Reward: -2.0448 | Pos: [-0.216, 0.019, 0.300] | Action: [-1.        1.        0.748523  1.       -0.41815   1.      ]
# Step 39/5000 | Time: 5.93s | Forward: 0.2359 m/s | Lateral: 0.0000 m/s | Reward: -2.9453 | Pos: [-0.216, 0.021, 0.300] | Action: [ 1.        0.103081 -1.        1.       -1.       -0.347975]
# Step 40/5000 | Time: 5.94s | Forward: 0.1414 m/s | Lateral: 0.0000 m/s | Reward: -3.8971 | Pos: [-0.217, 0.023, 0.300] | Action: [ 0.929484 -1.       -0.142385  0.164094 -1.       -0.389722]
# Step 41/5000 | Time: 5.95s | Forward: 0.0799 m/s | Lateral: 0.0000 m/s | Reward: -5.4270 | Pos: [-0.218, 0.023, 0.300] | Action: [ 0.037943  0.486533 -1.       -0.014377  1.       -1.      ]
# Step 42/5000 | Time: 5.96s | Forward: 0.1183 m/s | Lateral: 0.0000 m/s | Reward: -6.0123 | Pos: [-0.219, 0.022, 0.300] | Action: [-0.114161 -0.18085  -1.       -0.328796 -0.395412 -0.889827]
# Step 43/5000 | Time: 5.97s | Forward: 0.1533 m/s | Lateral: 0.0000 m/s | Reward: -3.3359 | Pos: [-0.220, 0.020, 0.300] | Action: [-0.742146 -0.14968   1.        0.440385 -1.        1.      ]
# Step 44/5000 | Time: 5.98s | Forward: 0.1744 m/s | Lateral: 0.0000 m/s | Reward: -4.3032 | Pos: [-0.221, 0.018, 0.300] | Action: [-1.        0.583659  0.005683 -1.       -0.296264 -1.      ]
# Step 45/5000 | Time: 5.99s | Forward: 0.2531 m/s | Lateral: 0.0000 m/s | Reward: -3.1972 | Pos: [-0.221, 0.016, 0.300] | Action: [ 1.       -1.        1.       -1.        0.243539 -0.558308]
# Step 46/5000 | Time: 6.01s | Forward: 0.0973 m/s | Lateral: 0.0000 m/s | Reward: -2.0766 | Pos: [-0.222, 0.015, 0.300] | Action: [ 0.51504   1.       -0.453777 -1.       -1.       -1.      ]
# Step 47/5000 | Time: 6.02s | Forward: 0.1431 m/s | Lateral: 0.0000 m/s | Reward: -2.1074 | Pos: [-0.221, 0.016, 0.300] | Action: [ 1.       -0.741148 -0.099839  1.       -1.        0.817069]
# Step 48/5000 | Time: 6.03s | Forward: 0.1323 m/s | Lateral: 0.0000 m/s | Reward: -4.1726 | Pos: [-0.221, 0.018, 0.300] | Action: [-0.558051  0.246406  1.       -1.       -0.007867 -1.      ]
# Step 49/5000 | Time: 6.04s | Forward: 0.0422 m/s | Lateral: 0.0000 m/s | Reward: -2.7568 | Pos: [-0.221, 0.018, 0.300] | Action: [-0.380965 -1.        0.85358  -1.       -0.157491 -0.813883]
# Step 50/5000 | Time: 6.05s | Forward: 0.0598 m/s | Lateral: 0.0000 m/s | Reward: -4.2899 | Pos: [-0.221, 0.018, 0.300] | Action: [-0.15649   1.        1.        1.        0.029126  1.      ]
# Step 51/5000 | Time: 6.06s | Forward: 0.1397 m/s | Lateral: 0.0000 m/s | Reward: -4.2784 | Pos: [-0.221, 0.016, 0.299] | Action: [ 0.121926  0.226811  1.        1.       -1.        1.      ]
# Step 52/5000 | Time: 6.07s | Forward: 0.1665 m/s | Lateral: 0.0000 m/s | Reward: -1.5146 | Pos: [-0.221, 0.014, 0.299] | Action: [ 1.       -1.       -1.        1.       -1.       -0.789553]
# Step 53/5000 | Time: 6.08s | Forward: 0.0786 m/s | Lateral: 0.0000 m/s | Reward: -1.8837 | Pos: [-0.222, 0.014, 0.300] | Action: [ 1.       -1.        1.       -1.        0.701025  0.429217]
# Step 54/5000 | Time: 6.09s | Forward: 0.2897 m/s | Lateral: 0.0000 m/s | Reward: -2.6406 | Pos: [-0.222, 0.017, 0.301] | Action: [ 1.       -1.       -0.227035  0.456071 -1.       -0.931805]
# Step 55/5000 | Time: 6.10s | Forward: 0.3978 m/s | Lateral: 0.0000 m/s | Reward: -2.7885 | Pos: [-0.223, 0.021, 0.303] | Action: [ 1.       -1.        0.56978  -1.       -0.783182  0.251147]
# Step 56/5000 | Time: 6.12s | Forward: 0.3142 m/s | Lateral: 0.0000 m/s | Reward: -0.8133 | Pos: [-0.223, 0.024, 0.305] | Action: [-0.968069  1.        1.       -1.       -1.        1.      ]
# Step 57/5000 | Time: 6.13s | Forward: 0.2288 m/s | Lateral: 0.0000 m/s | Reward: -1.5990 | Pos: [-0.224, 0.026, 0.306] | Action: [-1.       0.22663  1.       1.      -1.       1.     ]
# Step 58/5000 | Time: 6.14s | Forward: 0.1710 m/s | Lateral: 0.0000 m/s | Reward: -1.9768 | Pos: [-0.224, 0.027, 0.308] | Action: [-1.        0.245483  1.        0.561814  0.592786  1.      ]
# Step 59/5000 | Time: 6.15s | Forward: 0.1715 m/s | Lateral: 0.0000 m/s | Reward: -1.9461 | Pos: [-0.225, 0.026, 0.310] | Action: [ 0.158357  1.       -1.        1.        1.       -1.      ]
# Step 60/5000 | Time: 6.16s | Forward: 0.2298 m/s | Lateral: 0.0000 m/s | Reward: -0.7619 | Pos: [-0.225, 0.024, 0.311] | Action: [ 1.  1. -1.  1.  1. -1.]
# Step 61/5000 | Time: 6.17s | Forward: 0.2377 m/s | Lateral: 0.0000 m/s | Reward: -2.5255 | Pos: [-0.226, 0.022, 0.313] | Action: [ 1.       -1.       -1.        0.00267   0.539131 -1.      ]
# Step 62/5000 | Time: 6.18s | Forward: 0.1727 m/s | Lateral: 0.0000 m/s | Reward: -2.5738 | Pos: [-0.227, 0.021, 0.315] | Action: [ 0.357689 -1.       -1.       -0.544512 -1.       -1.      ]
# Step 63/5000 | Time: 6.19s | Forward: 0.2682 m/s | Lateral: 0.0000 m/s | Reward: -1.3574 | Pos: [-0.229, 0.023, 0.316] | Action: [ 1.       -0.929452 -0.506534 -1.        1.       -1.      ]
# Step 64/5000 | Time: 6.20s | Forward: 0.3250 m/s | Lateral: 0.0000 m/s | Reward: -3.4347 | Pos: [-0.231, 0.026, 0.317] | Action: [ 0.186089 -0.852105 -0.651417  1.        1.        0.14558 ]
# Step 65/5000 | Time: 6.21s | Forward: 0.2567 m/s | Lateral: 0.0000 m/s | Reward: -4.8077 | Pos: [-0.232, 0.028, 0.318] | Action: [-0.249027  0.168357 -1.        1.       -0.373572 -1.      ]
# Step 66/5000 | Time: 6.23s | Forward: 0.2154 m/s | Lateral: 0.0000 m/s | Reward: -2.7628 | Pos: [-0.234, 0.029, 0.319] | Action: [ 1.       -1.        0.168287 -1.        1.       -1.      ]
# Step 67/5000 | Time: 6.24s | Forward: 0.2097 m/s | Lateral: 0.0000 m/s | Reward: -3.4263 | Pos: [-0.236, 0.031, 0.320] | Action: [ 0.083676  1.       -0.936318  1.       -1.       -0.290263]
# Step 68/5000 | Time: 6.25s | Forward: 0.1631 m/s | Lateral: 0.0000 m/s | Reward: -2.8655 | Pos: [-0.237, 0.031, 0.320] | Action: [ 1.        0.928616 -0.266015 -1.       -0.329971 -1.      ]
# Step 69/5000 | Time: 6.26s | Forward: 0.1574 m/s | Lateral: 0.0000 m/s | Reward: -1.2071 | Pos: [-0.239, 0.031, 0.320] | Action: [ 1. -1.  1. -1.  1. -1.]
# Step 70/5000 | Time: 6.27s | Forward: 0.2148 m/s | Lateral: 0.0000 m/s | Reward: -2.3331 | Pos: [-0.241, 0.029, 0.321] | Action: [ 0.176356 -1.        1.       -1.        0.953158 -0.488683]
# Step 71/5000 | Time: 6.28s | Forward: 0.3013 m/s | Lateral: 0.0000 m/s | Reward: -1.6340 | Pos: [-0.242, 0.026, 0.321] | Action: [ 1.       -0.861638 -0.642033 -1.        0.621261 -1.      ]
# Step 72/5000 | Time: 6.29s | Forward: 0.3984 m/s | Lateral: 0.0000 m/s | Reward: -2.5738 | Pos: [-0.244, 0.022, 0.322] | Action: [-0.921997 -0.009335 -0.676972 -1.       -1.       -1.      ]
# Step 73/5000 | Time: 6.30s | Forward: 0.4860 m/s | Lateral: 0.0000 m/s | Reward: -3.6281 | Pos: [-0.246, 0.017, 0.322] | Action: [ 0.568365 -1.       -0.331581 -0.523991 -1.       -0.249267]
# Step 74/5000 | Time: 6.31s | Forward: 0.4854 m/s | Lateral: 0.0000 m/s | Reward: -3.0573 | Pos: [-0.248, 0.012, 0.322] | Action: [ 0.706479  0.544659 -1.        0.810509 -0.239266 -1.      ]
# Step 75/5000 | Time: 6.32s | Forward: 0.4142 m/s | Lateral: 0.0000 m/s | Reward: -2.7356 | Pos: [-0.250, 0.008, 0.321] | Action: [ 1.       -1.       -0.109385  1.       -0.303336 -1.      ]
# Step 76/5000 | Time: 6.34s | Forward: 0.2992 m/s | Lateral: 0.0000 m/s | Reward: -3.3798 | Pos: [-0.252, 0.006, 0.321] | Action: [ 0.099139 -0.297427 -1.        1.        1.        0.854883]
# Step 77/5000 | Time: 6.35s | Forward: 0.1816 m/s | Lateral: 0.0000 m/s | Reward: -3.5913 | Pos: [-0.254, 0.005, 0.320] | Action: [ 1.       -1.       -1.        0.146681  0.040077  1.      ]
# Step 78/5000 | Time: 6.36s | Forward: 0.1071 m/s | Lateral: 0.0000 m/s | Reward: -3.1038 | Pos: [-0.255, 0.005, 0.320] | Action: [-1.       -1.        1.       -0.139203 -0.971238  1.      ]
# Step 79/5000 | Time: 6.37s | Forward: 0.2361 m/s | Lateral: 0.0000 m/s | Reward: -1.1127 | Pos: [-0.255, 0.007, 0.319] | Action: [-1.  1.  1.  1.  1.  1.]
# Step 80/5000 | Time: 6.38s | Forward: 0.5034 m/s | Lateral: 0.0000 m/s | Reward: -1.8108 | Pos: [-0.255, 0.013, 0.319] | Action: [-0.262311  0.759164  0.936358  1.        1.        1.      ]
# Step 81/5000 | Time: 6.39s | Forward: 0.4930 m/s | Lateral: 0.0000 m/s | Reward: -0.9559 | Pos: [-0.255, 0.018, 0.318] | Action: [-0.60245  1.       1.       1.       1.       1.     ]
# Step 82/5000 | Time: 6.40s | Forward: 0.3923 m/s | Lateral: 0.0000 m/s | Reward: -0.9052 | Pos: [-0.256, 0.022, 0.318] | Action: [-0.585135  1.       -1.        1.        1.        1.      ]
# Step 83/5000 | Time: 6.41s | Forward: 0.3206 m/s | Lateral: 0.0000 m/s | Reward: -3.7863 | Pos: [-0.256, 0.026, 0.318] | Action: [-0.160545 -0.260026 -1.       -0.578843 -0.474741 -1.      ]
# Step 84/5000 | Time: 6.42s | Forward: 0.2175 m/s | Lateral: 0.0000 m/s | Reward: -4.0379 | Pos: [-0.256, 0.028, 0.318] | Action: [ 1.       -1.        0.24062   0.067747 -1.       -1.      ]
# Step 85/5000 | Time: 6.43s | Forward: 0.1104 m/s | Lateral: 0.0000 m/s | Reward: -4.0583 | Pos: [-0.256, 0.030, 0.318] | Action: [ 0.131205 -1.        1.        0.338177  0.117709  1.      ]
# Step 86/5000 | Time: 6.45s | Forward: 0.0196 m/s | Lateral: 0.0000 m/s | Reward: -1.4756 | Pos: [-0.257, 0.030, 0.318] | Action: [-1.        1.       -1.        1.        1.        0.844992]
# Step 87/5000 | Time: 6.46s | Forward: 0.0825 m/s | Lateral: 0.0000 m/s | Reward: -1.7563 | Pos: [-0.257, 0.029, 0.319] | Action: [ 1.       -1.       -1.       -0.398919  1.       -1.      ]
# Step 88/5000 | Time: 6.47s | Forward: 0.1628 m/s | Lateral: 0.0000 m/s | Reward: -3.4845 | Pos: [-0.257, 0.027, 0.319] | Action: [ 0.263563 -1.       -1.        0.346446 -0.524117 -1.      ]
# Step 89/5000 | Time: 6.48s | Forward: 0.2079 m/s | Lateral: 0.0000 m/s | Reward: -2.5720 | Pos: [-0.258, 0.025, 0.319] | Action: [ 0.199861 -1.       -1.        0.431939 -0.490471 -0.873335]
# Step 90/5000 | Time: 6.49s | Forward: 0.2927 m/s | Lateral: 0.0000 m/s | Reward: -1.8495 | Pos: [-0.258, 0.022, 0.319] | Action: [ 0.277253  1.       -1.        1.        1.       -1.      ]
# Step 91/5000 | Time: 6.50s | Forward: 0.3673 m/s | Lateral: 0.0000 m/s | Reward: -2.5106 | Pos: [-0.259, 0.018, 0.319] | Action: [ 1.       -0.090915 -1.        0.816741  1.        1.      ]
# Step 92/5000 | Time: 6.51s | Forward: 0.3011 m/s | Lateral: 0.0000 m/s | Reward: -0.9229 | Pos: [-0.259, 0.014, 0.320] | Action: [ 0.970785 -0.922153 -1.        1.        1.        1.      ]
# Step 93/5000 | Time: 6.52s | Forward: 0.1514 m/s | Lateral: 0.0000 m/s | Reward: -2.7740 | Pos: [-0.260, 0.013, 0.320] | Action: [-1.       -0.157272  1.        0.721182  0.295704  1.      ]
# Step 94/5000 | Time: 6.53s | Forward: 0.0815 m/s | Lateral: 0.0000 m/s | Reward: -2.0550 | Pos: [-0.260, 0.012, 0.320] | Action: [-0.717227  1.        1.        0.871719 -0.611716  1.      ]
# Step 95/5000 | Time: 6.54s | Forward: 0.0322 m/s | Lateral: 0.0000 m/s | Reward: -2.4410 | Pos: [-0.260, 0.012, 0.320] | Action: [ 1.       -0.965891  0.024553  1.       -1.        1.      ]
# Step 96/5000 | Time: 6.56s | Forward: 0.0385 m/s | Lateral: 0.0000 m/s | Reward: -2.5467 | Pos: [-0.260, 0.012, 0.320] | Action: [ 0.396237 -0.649234 -1.        1.       -1.       -0.642124]
# Step 97/5000 | Time: 6.57s | Forward: 0.1864 m/s | Lateral: 0.0000 m/s | Reward: -2.2507 | Pos: [-0.261, 0.014, 0.320] | Action: [ 0.370463 -0.729703 -0.628982  1.       -1.       -0.598741]
# Step 98/5000 | Time: 6.58s | Forward: 0.3198 m/s | Lateral: 0.0000 m/s | Reward: -3.6843 | Pos: [-0.260, 0.018, 0.321] | Action: [-0.423447  1.       -0.031691 -1.        1.       -0.39512 ]
# Step 99/5000 | Time: 6.59s | Forward: 0.2949 m/s | Lateral: 0.0000 m/s | Reward: -1.7077 | Pos: [-0.260, 0.021, 0.321] | Action: [ 0.772876 -1.        1.       -1.        0.68074  -0.835071]
# Step 100/5000 | Time: 6.60s | Forward: 0.1887 m/s | Lateral: 0.0000 m/s | Reward: -0.9313 | Pos: [-0.260, 0.023, 0.321] | Action: [-0.930404 -1.        1.        0.985098 -1.        1.      ]
# Step 101/5000 | Time: 6.61s | Forward: 0.0936 m/s | Lateral: 0.0000 m/s | Reward: -0.7382 | Pos: [-0.260, 0.024, 0.322] | Action: [-1.  1.  1.  1.  1.  1.]
# Step 102/5000 | Time: 6.62s | Forward: 0.0359 m/s | Lateral: 0.0000 m/s | Reward: -0.8271 | Pos: [-0.260, 0.024, 0.322] | Action: [-1.        0.733404  0.953787  0.758415  1.        1.      ]
# Step 103/5000 | Time: 6.63s | Forward: 0.0536 m/s | Lateral: 0.0000 m/s | Reward: -1.2582 | Pos: [-0.260, 0.025, 0.322] | Action: [-1.       -1.        0.699604  1.       -1.       -0.597855]
# Step 104/5000 | Time: 6.64s | Forward: 0.1463 m/s | Lateral: 0.0000 m/s | Reward: -0.8204 | Pos: [-0.260, 0.026, 0.323] | Action: [ 1. -1. -1.  1. -1. -1.]
# Step 105/5000 | Time: 6.65s | Forward: 0.1793 m/s | Lateral: 0.0000 m/s | Reward: -2.6312 | Pos: [-0.261, 0.027, 0.324] | Action: [ 0.592719  1.        0.086105  1.       -1.       -0.643965]
# Step 106/5000 | Time: 6.67s | Forward: 0.1487 m/s | Lateral: 0.0000 m/s | Reward: -2.3611 | Pos: [-0.261, 0.028, 0.326] | Action: [ 1.        0.128074  1.       -0.604532 -1.        1.      ]
# Step 107/5000 | Time: 6.68s | Forward: 0.1576 m/s | Lateral: 0.0000 m/s | Reward: -2.2511 | Pos: [-0.262, 0.027, 0.327] | Action: [ 0.282558  0.888444  1.       -0.56387  -1.        0.632993]
# Step 108/5000 | Time: 6.69s | Forward: 0.2255 m/s | Lateral: 0.0000 m/s | Reward: -1.5274 | Pos: [-0.263, 0.025, 0.328] | Action: [-1.        1.        1.       -1.        0.543632 -1.      ]
# Step 109/5000 | Time: 6.70s | Forward: 0.3165 m/s | Lateral: 0.0000 m/s | Reward: -0.8280 | Pos: [-0.264, 0.022, 0.330] | Action: [-1.       1.       1.      -1.       1.      -0.82662]
# Step 110/5000 | Time: 6.71s | Forward: 0.4156 m/s | Lateral: 0.0000 m/s | Reward: -1.6282 | Pos: [-0.265, 0.018, 0.331] | Action: [-1.        1.        1.       -1.        0.417587 -0.469689]
# Step 111/5000 | Time: 6.72s | Forward: 0.4708 m/s | Lateral: 0.0000 m/s | Reward: -2.4775 | Pos: [-0.266, 0.013, 0.332] | Action: [ 1.       -1.        1.       -1.        1.        0.127278]
# Step 112/5000 | Time: 6.73s | Forward: 0.3730 m/s | Lateral: 0.0000 m/s | Reward: -1.2619 | Pos: [-0.266, 0.009, 0.334] | Action: [ 1.       -1.       -0.560632 -1.        1.       -1.      ]
# Step 113/5000 | Time: 6.74s | Forward: 0.2117 m/s | Lateral: 0.0000 m/s | Reward: -3.1241 | Pos: [-0.267, 0.009, 0.337] | Action: [ 1.        0.363364 -0.289465 -0.258148  1.       -0.666064]
# Step 114/5000 | Time: 6.75s | Forward: 0.2810 m/s | Lateral: 0.0000 m/s | Reward: -2.1012 | Pos: [-0.267, 0.011, 0.339] | Action: [ 0.998897  1.       -0.254664  1.       -0.836309 -0.40705 ]
# Step 115/5000 | Time: 6.76s | Forward: 0.3495 m/s | Lateral: 0.0000 m/s | Reward: -0.7572 | Pos: [-0.266, 0.015, 0.340] | Action: [ 1.        1.       -1.        0.802024 -1.       -1.      ]
# Step 116/5000 | Time: 6.78s | Forward: 0.2727 m/s | Lateral: 0.0000 m/s | Reward: -1.5354 | Pos: [-0.266, 0.017, 0.342] | Action: [ 1.       -1.       -1.       -0.262183  1.       -1.      ]
# Step 117/5000 | Time: 6.79s | Forward: 0.1970 m/s | Lateral: 0.0000 m/s | Reward: -0.8108 | Pos: [-0.265, 0.018, 0.344] | Action: [ 1.        0.839921 -1.       -1.        1.       -0.708816]
# Step 118/5000 | Time: 6.80s | Forward: 0.1631 m/s | Lateral: 0.0000 m/s | Reward: -1.4171 | Pos: [-0.265, 0.018, 0.345] | Action: [-1.        1.        0.682481  0.39915   1.        1.      ]
# Step 119/5000 | Time: 6.81s | Forward: 0.1835 m/s | Lateral: 0.0000 m/s | Reward: -3.2656 | Pos: [-0.264, 0.017, 0.347] | Action: [-0.306719  0.823021 -0.463909  1.        1.        0.123666]
# Step 120/5000 | Time: 6.82s | Forward: 0.1928 m/s | Lateral: 0.0000 m/s | Reward: -4.5343 | Pos: [-0.264, 0.017, 0.349] | Action: [ 0.04862   1.       -0.046033 -1.        1.       -0.731791]
# Step 121/5000 | Time: 6.83s | Forward: 0.1788 m/s | Lateral: 0.0000 m/s | Reward: -2.1457 | Pos: [-0.265, 0.017, 0.351] | Action: [ 0.17868   1.       -1.        0.544019  1.        1.      ]
# Step 122/5000 | Time: 6.84s | Forward: 0.2010 m/s | Lateral: 0.0000 m/s | Reward: -3.0367 | Pos: [-0.265, 0.018, 0.353] | Action: [ 0.748476  1.       -0.425859  0.287347 -0.39471   0.611283]
# Step 123/5000 | Time: 6.85s | Forward: 0.2138 m/s | Lateral: 0.0000 m/s | Reward: -1.1837 | Pos: [-0.266, 0.020, 0.354] | Action: [ 1.       -1.       -0.859216  1.       -0.767784 -1.      ]
# Step 124/5000 | Time: 6.86s | Forward: 0.2491 m/s | Lateral: 0.0000 m/s | Reward: -3.1668 | Pos: [-0.267, 0.022, 0.355] | Action: [ 1.        0.376612 -0.393575 -0.466606  0.604637 -1.      ]
# Step 125/5000 | Time: 6.87s | Forward: 0.2003 m/s | Lateral: 0.0000 m/s | Reward: -4.2312 | Pos: [-0.268, 0.024, 0.356] | Action: [-0.457019  0.344323  1.        1.       -0.027857  1.      ]
# Step 126/5000 | Time: 6.89s | Forward: 0.1325 m/s | Lateral: 0.0000 m/s | Reward: -2.7327 | Pos: [-0.269, 0.024, 0.357] | Action: [-0.741685  0.197985 -0.417474  1.       -1.       -1.      ]
# Step 127/5000 | Time: 6.90s | Forward: 0.1351 m/s | Lateral: 0.0000 m/s | Reward: -2.0641 | Pos: [-0.270, 0.024, 0.358] | Action: [ 1.       -0.411766 -1.        1.       -1.       -1.      ]
# Step 128/5000 | Time: 6.91s | Forward: 0.2055 m/s | Lateral: 0.0000 m/s | Reward: -2.2424 | Pos: [-0.271, 0.022, 0.359] | Action: [ 1.       -0.002566  1.       -1.        0.814354  1.      ]
# Step 129/5000 | Time: 6.92s | Forward: 0.2991 m/s | Lateral: 0.0000 m/s | Reward: -1.1840 | Pos: [-0.272, 0.019, 0.360] | Action: [ 1.      -1.       1.      -1.      -0.83991  1.     ]
# Step 130/5000 | Time: 6.93s | Forward: 0.3725 m/s | Lateral: 0.0000 m/s | Reward: -1.9223 | Pos: [-0.273, 0.015, 0.361] | Action: [ 1.       -0.198211  1.        1.       -1.        1.      ]
# Step 131/5000 | Time: 6.94s | Forward: 0.2957 m/s | Lateral: 0.0000 m/s | Reward: -1.5759 | Pos: [-0.274, 0.012, 0.362] | Action: [ 0.429805  1.        1.        1.       -1.        1.      ]
# Step 132/5000 | Time: 6.95s | Forward: 0.0742 m/s | Lateral: 0.0000 m/s | Reward: -1.1135 | Pos: [-0.274, 0.012, 0.363] | Action: [-1.        1.        1.        0.456824 -1.        1.      ]
# Step 133/5000 | Time: 6.96s | Forward: 0.1787 m/s | Lateral: 0.0000 m/s | Reward: -3.1155 | Pos: [-0.274, 0.014, 0.364] | Action: [-0.853295 -0.202347  1.       -1.        0.15687   1.      ]
# Step 134/5000 | Time: 6.97s | Forward: 0.1963 m/s | Lateral: 0.0000 m/s | Reward: -0.9198 | Pos: [-0.274, 0.015, 0.365] | Action: [-1. -1.  1. -1. -1. -1.]
# Step 135/5000 | Time: 6.98s | Forward: 0.1206 m/s | Lateral: 0.0000 m/s | Reward: -0.4578 | Pos: [-0.273, 0.016, 0.366] | Action: [-1.       -1.        1.       -1.       -1.        0.643131]
# Step 136/5000 | Time: 7.00s | Forward: 0.1063 m/s | Lateral: 0.0000 m/s | Reward: -2.3454 | Pos: [-0.273, 0.016, 0.367] | Action: [-0.405897  1.        1.       -0.883775  0.069961  1.      ]
# Step 137/5000 | Time: 7.01s | Forward: 0.1770 m/s | Lateral: 0.0000 m/s | Reward: -2.6904 | Pos: [-0.273, 0.014, 0.368] | Action: [ 0.375909 -0.817442  1.       -1.        0.626054  0.259619]
# Step 138/5000 | Time: 7.02s | Forward: 0.2624 m/s | Lateral: 0.0000 m/s | Reward: -2.6054 | Pos: [-0.273, 0.011, 0.369] | Action: [-1.       -1.       -1.        1.        0.234397 -0.441975]
# Step 139/5000 | Time: 7.03s | Forward: 0.2426 m/s | Lateral: 0.0000 m/s | Reward: -2.2700 | Pos: [-0.272, 0.009, 0.370] | Action: [ 0.230373  1.       -1.        0.424309  1.       -1.      ]
# Step 140/5000 | Time: 7.04s | Forward: 0.1802 m/s | Lateral: 0.0000 m/s | Reward: -0.7882 | Pos: [-0.271, 0.010, 0.372] | Action: [ 1.        1.       -1.        0.457147  1.       -1.      ]
# Step 141/5000 | Time: 7.05s | Forward: 0.3177 m/s | Lateral: 0.0000 m/s | Reward: -1.7648 | Pos: [-0.270, 0.012, 0.373] | Action: [-0.468691 -1.       -1.        1.        1.       -0.377375]
# Step 142/5000 | Time: 7.06s | Forward: 0.3066 m/s | Lateral: 0.0000 m/s | Reward: -0.8530 | Pos: [-0.269, 0.015, 0.375] | Action: [-0.963287  1.       -0.823576  1.        1.        1.      ]
# Step 143/5000 | Time: 7.07s | Forward: 0.2301 m/s | Lateral: 0.0000 m/s | Reward: -1.0099 | Pos: [-0.268, 0.017, 0.376] | Action: [-1.        1.       -0.350351  1.        1.        0.97559 ]
# Step 144/5000 | Time: 7.08s | Forward: 0.1727 m/s | Lateral: 0.0000 m/s | Reward: -1.3118 | Pos: [-0.267, 0.018, 0.378] | Action: [ 0.560557  1.       -1.        1.        0.853845 -0.560653]
# Step 145/5000 | Time: 7.09s | Forward: 0.1724 m/s | Lateral: 0.0000 m/s | Reward: -2.4952 | Pos: [-0.266, 0.017, 0.379] | Action: [-0.029703 -1.        1.       -1.        1.       -0.62291 ]
# Step 146/5000 | Time: 7.11s | Forward: 0.1704 m/s | Lateral: 0.0000 m/s | Reward: -1.6468 | Pos: [-0.265, 0.017, 0.381] | Action: [-0.906393  0.224393  1.        0.985664 -1.        1.      ]
# Step 147/5000 | Time: 7.12s | Forward: 0.1571 m/s | Lateral: 0.0000 m/s | Reward: -0.8668 | Pos: [-0.264, 0.017, 0.383] | Action: [ 1.        1.       -1.        1.        1.       -0.567382]
# Step 148/5000 | Time: 7.13s | Forward: 0.1329 m/s | Lateral: 0.0000 m/s | Reward: -2.2791 | Pos: [-0.264, 0.016, 0.384] | Action: [-0.611131  1.        0.464423  0.447603  1.        0.670702]
# Step 149/5000 | Time: 7.14s | Forward: 0.1038 m/s | Lateral: 0.0000 m/s | Reward: -3.0698 | Pos: [-0.264, 0.016, 0.385] | Action: [ 0.699736  0.247504 -0.895412  0.091071  1.        0.738145]
# Step 150/5000 | Time: 7.15s | Forward: 0.1611 m/s | Lateral: 0.0000 m/s | Reward: -3.5930 | Pos: [-0.264, 0.014, 0.386] | Action: [-0.872012 -1.       -1.        0.607926  0.069464 -0.289945]
# Step 151/5000 | Time: 7.16s | Forward: 0.2395 m/s | Lateral: 0.0000 m/s | Reward: -2.4802 | Pos: [-0.264, 0.012, 0.387] | Action: [-1.        1.        1.        1.       -0.538638  0.610439]
# Step 152/5000 | Time: 7.17s | Forward: 0.2238 m/s | Lateral: 0.0000 m/s | Reward: -3.2291 | Pos: [-0.264, 0.009, 0.387] | Action: [ 1.        0.263894  0.32752  -0.528352  1.        0.61211 ]
# Step 153/5000 | Time: 7.18s | Forward: 0.1531 m/s | Lateral: 0.0000 m/s | Reward: -4.0491 | Pos: [-0.265, 0.008, 0.388] | Action: [ 1.       -0.925383 -1.        0.545075  0.02091  -0.50472 ]
# Step 154/5000 | Time: 7.19s | Forward: 0.1441 m/s | Lateral: 0.0000 m/s | Reward: -1.9734 | Pos: [-0.265, 0.007, 0.390] | Action: [ 1.        0.862087 -0.327795  1.       -0.832358  1.      ]
# Step 155/5000 | Time: 7.20s | Forward: 0.1909 m/s | Lateral: 0.0000 m/s | Reward: -1.1808 | Pos: [-0.264, 0.006, 0.391] | Action: [ 0.70465   1.       -1.        1.       -0.453956 -1.      ]
# Step 156/5000 | Time: 7.22s | Forward: 0.2116 m/s | Lateral: 0.0000 m/s | Reward: -4.4473 | Pos: [-0.264, 0.004, 0.393] | Action: [-0.550782  0.322175 -0.004801  0.786602 -0.311081 -0.568818]
# Step 157/5000 | Time: 7.23s | Forward: 0.1747 m/s | Lateral: 0.0000 m/s | Reward: -2.6244 | Pos: [-0.263, 0.004, 0.394] | Action: [ 1.        0.019003  1.       -1.        1.        0.932993]
# Step 158/5000 | Time: 7.24s | Forward: 0.2176 m/s | Lateral: 0.0000 m/s | Reward: -1.7679 | Pos: [-0.262, 0.005, 0.396] | Action: [ 1.       -1.        1.        0.678659 -1.       -0.580352]
# Step 159/5000 | Time: 7.25s | Forward: 0.4189 m/s | Lateral: 0.0000 m/s | Reward: -1.2261 | Pos: [-0.262, 0.010, 0.396] | Action: [-1.        1.        1.        1.       -1.        0.691619]
# Step 160/5000 | Time: 7.26s | Forward: 0.5152 m/s | Lateral: 0.0000 m/s | Reward: -2.0326 | Pos: [-0.261, 0.015, 0.397] | Action: [ 0.804536  0.763672  1.       -1.        0.279624 -1.      ]
# Step 161/5000 | Time: 7.27s | Forward: 0.4677 m/s | Lateral: 0.0000 m/s | Reward: -1.7040 | Pos: [-0.261, 0.021, 0.397] | Action: [ 1.       -1.        1.       -0.997743 -0.701959 -0.559729]
# Step 162/5000 | Time: 7.28s | Forward: 0.3717 m/s | Lateral: 0.0000 m/s | Reward: -1.8183 | Pos: [-0.261, 0.025, 0.397] | Action: [ 1.       -0.326201  0.666323 -1.        1.       -1.      ]
# Step 163/5000 | Time: 7.29s | Forward: 0.2641 m/s | Lateral: 0.0000 m/s | Reward: -3.4610 | Pos: [-0.261, 0.028, 0.398] | Action: [ 0.110623  1.        0.295351  1.       -0.606109  1.      ]
# Step 164/5000 | Time: 7.30s | Forward: 0.1568 m/s | Lateral: 0.0000 m/s | Reward: -2.5468 | Pos: [-0.261, 0.029, 0.398] | Action: [-1.        0.100878  1.        1.       -1.        1.      ]
# Step 165/5000 | Time: 7.31s | Forward: 0.0520 m/s | Lateral: 0.0000 m/s | Reward: -2.5976 | Pos: [-0.261, 0.030, 0.398] | Action: [-0.30006   0.120618 -1.        1.        1.       -1.      ]
# Step 166/5000 | Time: 7.33s | Forward: 0.0640 m/s | Lateral: 0.0000 m/s | Reward: -1.5111 | Pos: [-0.261, 0.029, 0.398] | Action: [-0.946352 -1.       -1.        1.       -1.       -0.495247]
# Step 167/5000 | Time: 7.34s | Forward: 0.1696 m/s | Lateral: 0.0000 m/s | Reward: -4.5840 | Pos: [-0.260, 0.027, 0.398] | Action: [0.414051 1.       0.393216 0.043383 1.       0.469665]
# Step 168/5000 | Time: 7.35s | Forward: 0.2769 m/s | Lateral: 0.0000 m/s | Reward: -2.0630 | Pos: [-0.260, 0.024, 0.398] | Action: [ 1.        0.624355  0.823187 -1.        1.        0.470768]
# Step 169/5000 | Time: 7.36s | Forward: 0.3820 m/s | Lateral: 0.0000 m/s | Reward: -2.0064 | Pos: [-0.260, 0.020, 0.399] | Action: [-1.       -1.        1.       -1.       -1.        0.123594]
# Step 170/5000 | Time: 7.37s | Forward: 0.4052 m/s | Lateral: 0.0000 m/s | Reward: -1.9046 | Pos: [-0.260, 0.016, 0.399] | Action: [ 0.325905 -1.        1.        1.       -1.        1.      ]
# Step 171/5000 | Time: 7.38s | Forward: 0.3785 m/s | Lateral: 0.0000 m/s | Reward: -2.0360 | Pos: [-0.260, 0.011, 0.399] | Action: [ 1.       -0.403716 -0.858184 -1.        1.       -0.547798]
# Step 172/5000 | Time: 7.39s | Forward: 0.3619 m/s | Lateral: 0.0000 m/s | Reward: -4.7935 | Pos: [-0.260, 0.007, 0.399] | Action: [ 0.258924  1.        1.       -0.122326 -0.025231  1.      ]
# Step 173/5000 | Time: 7.40s | Forward: 0.2770 m/s | Lateral: 0.0000 m/s | Reward: -2.8466 | Pos: [-0.260, 0.004, 0.398] | Action: [ 1.       -1.       -0.490354 -0.334511 -1.        0.447166]
# Step 174/5000 | Time: 7.41s | Forward: 0.1078 m/s | Lateral: 0.0000 m/s | Reward: -1.8828 | Pos: [-0.260, 0.004, 0.397] | Action: [ 0.34615  -1.        1.       -0.92873  -0.902768  1.      ]
# Step 175/5000 | Time: 7.42s | Forward: 0.1683 m/s | Lateral: 0.0000 m/s | Reward: -0.8691 | Pos: [-0.260, 0.005, 0.397] | Action: [ 1.  1. -1. -1.  1. -1.]
# Step 176/5000 | Time: 7.44s | Forward: 0.2835 m/s | Lateral: 0.0000 m/s | Reward: -2.4190 | Pos: [-0.260, 0.008, 0.396] | Action: [ 0.037371 -1.       -1.        1.       -1.        0.81137 ]
# Step 177/5000 | Time: 7.45s | Forward: 0.4022 m/s | Lateral: 0.0000 m/s | Reward: -1.2207 | Pos: [-0.261, 0.013, 0.395] | Action: [ 1.     -1.     -0.7409 -1.      1.     -1.    ]
# Step 178/5000 | Time: 7.46s | Forward: 0.3299 m/s | Lateral: 0.0000 m/s | Reward: -1.3990 | Pos: [-0.261, 0.016, 0.394] | Action: [-1.       -1.        0.987906 -1.        1.       -0.359846]
# Step 179/5000 | Time: 7.47s | Forward: 0.2276 m/s | Lateral: 0.0000 m/s | Reward: -1.9634 | Pos: [-0.261, 0.019, 0.393] | Action: [ 0.95392   1.       -1.        1.        1.       -0.059947]
# Step 180/5000 | Time: 7.48s | Forward: 0.1343 m/s | Lateral: 0.0000 m/s | Reward: -2.3844 | Pos: [-0.262, 0.020, 0.392] | Action: [ 1.        0.387564  0.406414  0.642934  1.       -0.852572]
# Step 181/5000 | Time: 7.49s | Forward: 0.0870 m/s | Lateral: 0.0000 m/s | Reward: -4.3590 | Pos: [-0.262, 0.020, 0.392] | Action: [ 0.606076 -1.        0.100916 -0.267663 -1.        0.319795]
# Step 182/5000 | Time: 7.50s | Forward: 0.1427 m/s | Lateral: 0.0000 m/s | Reward: -2.4892 | Pos: [-0.262, 0.018, 0.391] | Action: [ 1.        1.       -1.       -1.        1.        0.002601]
# Step 183/5000 | Time: 7.51s | Forward: 0.2337 m/s | Lateral: 0.0000 m/s | Reward: -3.2016 | Pos: [-0.263, 0.016, 0.390] | Action: [-0.297657 -0.260956  0.73061   0.958476 -1.        1.      ]
# Step 184/5000 | Time: 7.52s | Forward: 0.2994 m/s | Lateral: 0.0000 m/s | Reward: -3.6233 | Pos: [-0.263, 0.013, 0.389] | Action: [-1.        0.3061   -0.172401  1.       -0.936269  1.      ]
# Step 185/5000 | Time: 7.53s | Forward: 0.3104 m/s | Lateral: 0.0000 m/s | Reward: -3.5638 | Pos: [-0.263, 0.009, 0.389] | Action: [-1.        0.140546  0.599166 -0.325609  1.       -0.886718]
# Step 186/5000 | Time: 7.55s | Forward: 0.3205 m/s | Lateral: 0.0000 m/s | Reward: -2.0978 | Pos: [-0.264, 0.006, 0.388] | Action: [ 1.        1.        1.       -0.052603  1.        1.      ]
# Step 187/5000 | Time: 7.56s | Forward: 0.3046 m/s | Lateral: 0.0000 m/s | Reward: -2.6529 | Pos: [-0.264, 0.003, 0.388] | Action: [-0.737299  1.       -1.        1.        0.071381 -1.      ]
# Step 188/5000 | Time: 7.57s | Forward: 0.1903 m/s | Lateral: 0.0000 m/s | Reward: -5.3118 | Pos: [-0.264, 0.001, 0.387] | Action: [ 0.27638  -0.585837  1.        0.12017  -1.       -0.023036]
# Step 189/5000 | Time: 7.58s | Forward: 0.0515 m/s | Lateral: 0.0000 m/s | Reward: -3.9900 | Pos: [-0.264, 0.000, 0.387] | Action: [-0.186244 -0.48138  -1.       -0.57844   1.       -1.      ]
# Step 190/5000 | Time: 7.59s | Forward: 0.2569 m/s | Lateral: 0.0000 m/s | Reward: -5.8132 | Pos: [-0.264, 0.003, 0.387] | Action: [ 0.245419  1.       -0.012007  1.       -0.022613  0.778383]
# Step 191/5000 | Time: 7.60s | Forward: 0.4429 m/s | Lateral: 0.0000 m/s | Reward: -2.1293 | Pos: [-0.263, 0.008, 0.387] | Action: [-0.685794  1.        1.        0.881136  1.        1.      ]
# Step 192/5000 | Time: 7.61s | Forward: 0.4555 m/s | Lateral: 0.0000 m/s | Reward: -2.8789 | Pos: [-0.263, 0.013, 0.388] | Action: [-0.147091  1.       -0.932479  1.       -0.197886 -1.      ]
# Step 193/5000 | Time: 7.62s | Forward: 0.3508 m/s | Lateral: 0.0000 m/s | Reward: -1.8251 | Pos: [-0.263, 0.017, 0.389] | Action: [ 0.456147 -1.       -1.        1.       -0.775126 -1.      ]
# Step 194/5000 | Time: 7.63s | Forward: 0.2604 m/s | Lateral: 0.0000 m/s | Reward: -1.4131 | Pos: [-0.263, 0.019, 0.390] | Action: [ 1.        0.511767 -1.       -1.        0.827582 -1.      ]
# Step 195/5000 | Time: 7.64s | Forward: 0.1796 m/s | Lateral: 0.0000 m/s | Reward: -1.6862 | Pos: [-0.263, 0.021, 0.391] | Action: [-0.835965 -1.       -0.343393 -1.       -1.       -1.      ]
# Step 196/5000 | Time: 7.66s | Forward: 0.1110 m/s | Lateral: 0.0000 m/s | Reward: -1.4025 | Pos: [-0.263, 0.022, 0.392] | Action: [ 1.        1.        1.       -1.        0.486387 -1.      ]
# Step 197/5000 | Time: 7.67s | Forward: 0.0935 m/s | Lateral: 0.0000 m/s | Reward: -2.0118 | Pos: [-0.263, 0.022, 0.393] | Action: [ 1.       -1.       -0.384562 -0.384875 -1.       -1.      ]
# Step 198/5000 | Time: 7.68s | Forward: 0.0967 m/s | Lateral: 0.0000 m/s | Reward: -1.8359 | Pos: [-0.263, 0.022, 0.394] | Action: [ 1.       -1.       -0.214458 -1.        1.       -0.447949]
# Step 199/5000 | Time: 7.69s | Forward: 0.1229 m/s | Lateral: 0.0000 m/s | Reward: -2.0820 | Pos: [-0.263, 0.022, 0.395] | Action: [-0.732776 -1.       -0.495724 -0.254849  1.        1.      ]
# Step 200/5000 | Time: 7.70s | Forward: 0.1861 m/s | Lateral: 0.0000 m/s | Reward: -2.8773 | Pos: [-0.263, 0.020, 0.396] | Action: [ 0.00299  1.      -1.       1.       0.80891  0.98972]
# Step 201/5000 | Time: 7.71s | Forward: 0.2267 m/s | Lateral: 0.0000 m/s | Reward: -1.6116 | Pos: [-0.263, 0.018, 0.397] | Action: [-1.        1.        1.        1.        0.372971 -0.970851]
# Step 202/5000 | Time: 7.72s | Forward: 0.2432 m/s | Lateral: 0.0000 m/s | Reward: -2.6032 | Pos: [-0.264, 0.016, 0.399] | Action: [-1.        0.676912 -0.797916  1.       -0.940709 -0.085713]
# Step 203/5000 | Time: 7.73s | Forward: 0.2989 m/s | Lateral: 0.0000 m/s | Reward: -5.1236 | Pos: [-0.264, 0.013, 0.401] | Action: [-0.016954 -0.421815  1.       -1.        0.066341  1.      ]
# Step 204/5000 | Time: 7.74s | Forward: 0.3948 m/s | Lateral: 0.0000 m/s | Reward: -6.0188 | Pos: [-0.265, 0.009, 0.402] | Action: [ 0.423977 -0.358442 -0.205346  0.450575 -0.350641 -1.      ]
# Step 205/5000 | Time: 7.75s | Forward: 0.4572 m/s | Lateral: 0.0000 m/s | Reward: -3.0079 | Pos: [-0.265, 0.004, 0.404] | Action: [-0.799145 -0.465327  1.       -1.       -0.126284 -1.      ]
# Step 206/5000 | Time: 7.77s | Forward: 0.2619 m/s | Lateral: 0.0000 m/s | Reward: -2.1379 | Pos: [-0.267, 0.002, 0.406] | Action: [ 0.997657  0.441193 -1.       -0.926737  1.       -1.      ]
# Step 207/5000 | Time: 7.78s | Forward: 0.3468 m/s | Lateral: 0.0000 m/s | Reward: -5.5033 | Pos: [-0.267, 0.006, 0.407] | Action: [ 0.18008   0.466533 -0.521184 -0.062491 -0.203055 -1.      ]
# Step 208/5000 | Time: 7.79s | Forward: 0.3847 m/s | Lateral: 0.0000 m/s | Reward: -5.4991 | Pos: [-0.267, 0.010, 0.408] | Action: [ 1.       -0.062767  0.024942 -1.       -1.       -1.      ]
# Step 209/5000 | Time: 7.80s | Forward: 0.3214 m/s | Lateral: 0.0000 m/s | Reward: -2.7697 | Pos: [-0.268, 0.014, 0.408] | Action: [ 1.        1.       -1.        0.861299  0.261029 -1.      ]
# Step 210/5000 | Time: 7.81s | Forward: 0.4146 m/s | Lateral: 0.0000 m/s | Reward: -4.7452 | Pos: [-0.267, 0.018, 0.409] | Action: [-0.046215  0.069972  1.       -1.        0.50667  -0.507288]
# Step 211/5000 | Time: 7.82s | Forward: 0.3978 m/s | Lateral: 0.0000 m/s | Reward: -3.2679 | Pos: [-0.267, 0.023, 0.409] | Action: [ 0.905208 -1.       -0.164272 -0.950772 -1.       -1.      ]
# Step 212/5000 | Time: 7.83s | Forward: 0.2947 m/s | Lateral: 0.0000 m/s | Reward: -2.2300 | Pos: [-0.267, 0.026, 0.409] | Action: [ 1.       -1.        1.       -1.        1.        0.300578]
# Step 213/5000 | Time: 7.84s | Forward: 0.1887 m/s | Lateral: 0.0000 m/s | Reward: -1.0509 | Pos: [-0.266, 0.028, 0.410] | Action: [ 1.  1. -1. -1.  1. -1.]
# Step 214/5000 | Time: 7.85s | Forward: 0.0873 m/s | Lateral: 0.0000 m/s | Reward: -3.6041 | Pos: [-0.266, 0.029, 0.410] | Action: [ 0.109108 -0.033616  1.       -1.        0.821632 -1.      ]
# Step 215/5000 | Time: 7.86s | Forward: 0.0489 m/s | Lateral: 0.0000 m/s | Reward: -2.9174 | Pos: [-0.266, 0.028, 0.410] | Action: [-0.723503  0.412822  1.       -1.        1.       -0.374805]
# Step 216/5000 | Time: 7.88s | Forward: 0.1026 m/s | Lateral: 0.0000 m/s | Reward: -1.5708 | Pos: [-0.265, 0.027, 0.411] | Action: [ 1.       -1.        1.       -1.       -1.       -0.264768]
# Step 217/5000 | Time: 7.89s | Forward: 0.1200 m/s | Lateral: 0.0000 m/s | Reward: -2.3030 | Pos: [-0.265, 0.026, 0.411] | Action: [ 0.293514  1.        1.       -1.        1.       -0.169588]
# Step 218/5000 | Time: 7.90s | Forward: 0.1931 m/s | Lateral: 0.0000 m/s | Reward: -3.5455 | Pos: [-0.264, 0.024, 0.411] | Action: [-0.02171   1.       -0.552652  0.975933  1.       -1.      ]
# Step 219/5000 | Time: 7.91s | Forward: 0.2973 m/s | Lateral: 0.0000 m/s | Reward: -4.3559 | Pos: [-0.263, 0.021, 0.411] | Action: [-0.043587  0.326523  0.559337  0.201687 -1.       -1.      ]
# Step 220/5000 | Time: 7.92s | Forward: 0.4035 m/s | Lateral: 0.0000 m/s | Reward: -3.4567 | Pos: [-0.263, 0.017, 0.411] | Action: [-1.        0.907401  1.        1.        0.348648  0.12396 ]
# Step 221/5000 | Time: 7.93s | Forward: 0.5101 m/s | Lateral: 0.0000 m/s | Reward: -2.0040 | Pos: [-0.262, 0.011, 0.411] | Action: [ 1.      -1.       1.       1.      -1.      -0.54487]
# Step 222/5000 | Time: 7.94s | Forward: 0.4528 m/s | Lateral: 0.0000 m/s | Reward: -1.1937 | Pos: [-0.261, 0.006, 0.412] | Action: [-1.       -0.620675  1.        0.767655 -1.        1.      ]
# Step 223/5000 | Time: 7.95s | Forward: 0.0934 m/s | Lateral: 0.0000 m/s | Reward: -3.7956 | Pos: [-0.261, 0.005, 0.412] | Action: [-0.306651 -0.363486  1.       -0.728969 -0.02121   1.      ]
# Step 224/5000 | Time: 7.96s | Forward: 0.2159 m/s | Lateral: 0.0000 m/s | Reward: -3.6515 | Pos: [-0.262, 0.008, 0.413] | Action: [ 1.       -0.159468  1.        0.372853 -0.160756  1.      ]
# Step 225/5000 | Time: 7.97s | Forward: 0.1537 m/s | Lateral: 0.0000 m/s | Reward: -4.8775 | Pos: [-0.262, 0.009, 0.414] | Action: [ 1.        1.       -0.167541 -0.50526   0.189479 -1.      ]
# Step 226/5000 | Time: 7.99s | Forward: 0.1015 m/s | Lateral: 0.0000 m/s | Reward: -3.3910 | Pos: [-0.262, 0.009, 0.415] | Action: [ 1.       -1.        0.425207  0.228293 -1.       -1.      ]
# Step 227/5000 | Time: 8.00s | Forward: 0.1602 m/s | Lateral: 0.0000 m/s | Reward: -2.8234 | Pos: [-0.262, 0.010, 0.417] | Action: [-0.648831 -0.614918 -1.        1.       -1.        0.156979]
# Step 228/5000 | Time: 8.01s | Forward: 0.2918 m/s | Lateral: 0.0000 m/s | Reward: -1.7554 | Pos: [-0.263, 0.013, 0.418] | Action: [0.684271 1.       0.823417 1.       1.       0.554835]
# Step 229/5000 | Time: 8.02s | Forward: 0.3986 m/s | Lateral: 0.0000 m/s | Reward: -1.4662 | Pos: [-0.265, 0.017, 0.419] | Action: [-0.45233  1.      -1.       1.       1.       1.     ]
# Step 230/5000 | Time: 8.03s | Forward: 0.3266 m/s | Lateral: 0.0000 m/s | Reward: -4.0674 | Pos: [-0.267, 0.020, 0.421] | Action: [-0.074028  0.320243 -1.       -0.151623  1.       -0.692483]
# Step 231/5000 | Time: 8.04s | Forward: 0.2571 m/s | Lateral: 0.0000 m/s | Reward: -4.3944 | Pos: [-0.268, 0.022, 0.422] | Action: [-1.       -1.        0.414263  0.189023 -0.716687  0.615177]
# Step 232/5000 | Time: 8.05s | Forward: 0.2022 m/s | Lateral: 0.0000 m/s | Reward: -4.6178 | Pos: [-0.270, 0.023, 0.423] | Action: [-0.222334  0.195928  0.495729 -1.        1.       -0.39316 ]
# Step 233/5000 | Time: 8.06s | Forward: 0.1868 m/s | Lateral: 0.0000 m/s | Reward: -4.8422 | Pos: [-0.271, 0.023, 0.425] | Action: [0.27012  0.850263 0.126879 1.       0.166923 0.823504]
# Step 234/5000 | Time: 8.07s | Forward: 0.2284 m/s | Lateral: 0.0000 m/s | Reward: -1.6915 | Pos: [-0.273, 0.021, 0.426] | Action: [-1.        1.        1.       -0.535781  0.894904  1.      ]
# Step 235/5000 | Time: 8.08s | Forward: 0.3043 m/s | Lateral: 0.0000 m/s | Reward: -1.1211 | Pos: [-0.274, 0.018, 0.427] | Action: [-1.        1.        1.       -1.       -0.596158  1.      ]
# Step 236/5000 | Time: 8.10s | Forward: 0.2997 m/s | Lateral: 0.0000 m/s | Reward: -1.0200 | Pos: [-0.276, 0.016, 0.429] | Action: [-0.691231 -1.        1.        1.       -1.        1.      ]
# Step 237/5000 | Time: 8.11s | Forward: 0.2180 m/s | Lateral: 0.0000 m/s | Reward: -2.6304 | Pos: [-0.278, 0.015, 0.429] | Action: [ 1.        0.664142  0.14736   0.781103 -1.       -0.815502]
# Step 238/5000 | Time: 8.12s | Forward: 0.2037 m/s | Lateral: 0.0000 m/s | Reward: -1.3408 | Pos: [-0.280, 0.015, 0.430] | Action: [-1.        1.       -0.937507  1.       -1.       -0.75462 ]
# Step 239/5000 | Time: 8.13s | Forward: 0.1901 m/s | Lateral: 0.0000 m/s | Reward: -2.6465 | Pos: [-0.282, 0.015, 0.430] | Action: [-0.527871  1.        0.897196  1.       -0.138254  1.      ]
# Step 240/5000 | Time: 8.14s | Forward: 0.2168 m/s | Lateral: 0.0000 m/s | Reward: -6.1736 | Pos: [-0.284, 0.017, 0.431] | Action: [-0.106668  0.461511  1.       -0.026137  0.098546  0.901946]
# Step 241/5000 | Time: 8.15s | Forward: 0.2151 m/s | Lateral: 0.0000 m/s | Reward: -5.3579 | Pos: [-0.285, 0.018, 0.432] | Action: [0.172067 1.       1.       0.087372 1.       1.      ]
# Step 242/5000 | Time: 8.16s | Forward: 0.1722 m/s | Lateral: 0.0000 m/s | Reward: -2.2698 | Pos: [-0.287, 0.018, 0.433] | Action: [-1.        0.773659 -0.457931  1.       -1.        1.      ]
# Step 243/5000 | Time: 8.17s | Forward: 0.1612 m/s | Lateral: 0.0000 m/s | Reward: -3.7037 | Pos: [-0.289, 0.018, 0.434] | Action: [-1.       -0.110842  1.       -1.       -1.       -0.268929]
# Step 244/5000 | Time: 8.18s | Forward: 0.1654 m/s | Lateral: 0.0000 m/s | Reward: -3.6004 | Pos: [-0.290, 0.018, 0.434] | Action: [ 0.292449 -1.        1.       -0.220491 -0.429645 -1.      ]
# Step 245/5000 | Time: 8.19s | Forward: 0.1750 m/s | Lateral: 0.0000 m/s | Reward: -5.5683 | Pos: [-0.292, 0.017, 0.436] | Action: [-0.038821  0.855836 -0.049103  0.671947  1.        1.      ]
# Step 246/5000 | Time: 8.21s | Forward: 0.1462 m/s | Lateral: 0.0000 m/s | Reward: -3.0440 | Pos: [-0.293, 0.016, 0.437] | Action: [-0.349165  0.134991  1.       -1.        1.        1.      ]
# Step 247/5000 | Time: 8.22s | Forward: 0.1569 m/s | Lateral: 0.0000 m/s | Reward: -1.8074 | Pos: [-0.294, 0.016, 0.438] | Action: [ 1.       -1.       -1.        0.893241 -0.579534 -1.      ]
# Step 248/5000 | Time: 8.23s | Forward: 0.2019 m/s | Lateral: 0.0000 m/s | Reward: -2.5891 | Pos: [-0.296, 0.015, 0.439] | Action: [ 0.423107  0.324599 -0.868077  1.       -1.       -1.      ]
# Step 249/5000 | Time: 8.24s | Forward: 0.2733 m/s | Lateral: 0.0000 m/s | Reward: -2.1187 | Pos: [-0.297, 0.012, 0.440] | Action: [-0.455203  1.        1.       -1.        1.        1.      ]
# Step 250/5000 | Time: 8.25s | Forward: 0.2325 m/s | Lateral: 0.0000 m/s | Reward: -2.6958 | Pos: [-0.298, 0.010, 0.441] | Action: [-1.        1.        1.       -0.382008 -0.286075  1.      ]
# Step 251/5000 | Time: 8.26s | Forward: 0.2699 m/s | Lateral: 0.0000 m/s | Reward: -2.9887 | Pos: [-0.299, 0.013, 0.442] | Action: [ 0.711711  0.459866  1.       -0.562369 -0.167976  1.      ]
# Step 252/5000 | Time: 8.27s | Forward: 0.4026 m/s | Lateral: 0.0000 m/s | Reward: -4.4107 | Pos: [-0.300, 0.017, 0.443] | Action: [ 0.341482 -1.        1.        0.285374 -1.        0.118574]
# ...
# Step 4918/5000 | Time: 59.60s | Forward: 0.5661 m/s | Lateral: 0.0000 m/s | Reward: -2.9447 | Pos: [-0.954, 0.012, 0.223] | Action: [-0.536663 -0.13271   1.       -1.        1.        1.      ]
# Step 4919/5000 | Time: 59.61s | Forward: 0.5250 m/s | Lateral: 0.0000 m/s | Reward: -1.7782 | Pos: [-0.953, 0.018, 0.223] | Action: [-1.       -1.        0.524043 -1.        1.       -0.491192]
# Step 4920/5000 | Time: 59.62s | Forward: 0.4306 m/s | Lateral: 0.0000 m/s | Reward: -1.9672 | Pos: [-0.953, 0.023, 0.223] | Action: [ 1.      -1.       1.      -1.       0.16836  1.     ]
# Step 4921/5000 | Time: 59.63s | Forward: 0.3257 m/s | Lateral: 0.0000 m/s | Reward: -3.7563 | Pos: [-0.953, 0.026, 0.223] | Action: [-1.        0.799444  0.293377 -0.494036  1.        0.024019]
# Step 4922/5000 | Time: 59.64s | Forward: 0.2184 m/s | Lateral: 0.0000 m/s | Reward: -3.6335 | Pos: [-0.953, 0.029, 0.223] | Action: [ 0.143924 -1.        1.       -0.109779 -0.722304  1.      ]
# Step 4923/5000 | Time: 59.65s | Forward: 0.1121 m/s | Lateral: 0.0000 m/s | Reward: -2.7219 | Pos: [-0.952, 0.030, 0.223] | Action: [ 1.       -1.        0.534916  0.295203 -0.827101  1.      ]
# Step 4924/5000 | Time: 59.66s | Forward: 0.0270 m/s | Lateral: 0.0000 m/s | Reward: -0.8259 | Pos: [-0.952, 0.030, 0.223] | Action: [ 1.        1.        1.       -0.932254 -1.        0.590496]
# Step 4925/5000 | Time: 59.68s | Forward: 0.1103 m/s | Lateral: 0.0000 m/s | Reward: -2.9722 | Pos: [-0.952, 0.029, 0.223] | Action: [ 1.        1.       -1.        1.       -0.401969 -0.139659]
# Step 4926/5000 | Time: 59.69s | Forward: 0.2165 m/s | Lateral: 0.0000 m/s | Reward: -2.8644 | Pos: [-0.951, 0.026, 0.223] | Action: [-0.303922  0.383794  0.912579  0.645164 -1.       -1.      ]
# Step 4927/5000 | Time: 59.70s | Forward: 0.2936 m/s | Lateral: 0.0000 m/s | Reward: -2.2449 | Pos: [-0.951, 0.023, 0.223] | Action: [-0.286388  0.734739 -0.421281  1.       -1.       -1.      ]
# Step 4928/5000 | Time: 59.71s | Forward: 0.3430 m/s | Lateral: 0.0000 m/s | Reward: -0.9143 | Pos: [-0.951, 0.019, 0.223] | Action: [-1.  1.  1.  1. -1.  1.]
# Step 4929/5000 | Time: 59.72s | Forward: 0.3757 m/s | Lateral: 0.0000 m/s | Reward: -1.1228 | Pos: [-0.951, 0.015, 0.223] | Action: [-0.512545  1.        1.        1.       -1.        1.      ]
# Step 4930/5000 | Time: 59.73s | Forward: 0.3394 m/s | Lateral: 0.0000 m/s | Reward: -0.5391 | Pos: [-0.950, 0.012, 0.223] | Action: [-1.  1.  1.  1. -1.  1.]
# Step 4931/5000 | Time: 59.74s | Forward: 0.3431 m/s | Lateral: 0.0000 m/s | Reward: -2.1740 | Pos: [-0.948, 0.008, 0.223] | Action: [-0.702189  1.       -1.        1.       -1.       -0.089091]
# Step 4932/5000 | Time: 59.75s | Forward: 0.2979 m/s | Lateral: 0.0000 m/s | Reward: -2.4959 | Pos: [-0.947, 0.005, 0.223] | Action: [ 0.099415  1.        1.       -1.        0.900192 -0.815403]
# Step 4933/5000 | Time: 59.76s | Forward: 0.2404 m/s | Lateral: 0.0000 m/s | Reward: -1.8431 | Pos: [-0.946, 0.003, 0.223] | Action: [ 0.914611  0.243505 -1.        1.        1.        1.      ]
# Step 4934/5000 | Time: 59.77s | Forward: 0.1649 m/s | Lateral: 0.0000 m/s | Reward: -1.4885 | Pos: [-0.944, 0.002, 0.222] | Action: [-1.        0.821933  0.746828  1.       -1.        0.428065]
# Step 4935/5000 | Time: 59.79s | Forward: 0.2099 m/s | Lateral: 0.0000 m/s | Reward: -0.7522 | Pos: [-0.942, 0.003, 0.221] | Action: [-1.       -1.        1.        1.       -1.        0.488288]
# Step 4936/5000 | Time: 59.80s | Forward: 0.2340 m/s | Lateral: 0.0000 m/s | Reward: -2.7480 | Pos: [-0.940, 0.003, 0.220] | Action: [ 0.02493   1.        1.        0.446909 -1.        1.      ]
# Step 4937/5000 | Time: 59.81s | Forward: 0.3394 m/s | Lateral: 0.0000 m/s | Reward: -0.8345 | Pos: [-0.938, 0.006, 0.220] | Action: [ 1.  1.  1. -1. -1.  1.]
# Step 4938/5000 | Time: 59.82s | Forward: 0.3949 m/s | Lateral: 0.0000 m/s | Reward: -1.3437 | Pos: [-0.936, 0.010, 0.219] | Action: [-1.        1.        1.       -1.       -0.277448 -0.917825]
# Step 4939/5000 | Time: 59.83s | Forward: 0.3149 m/s | Lateral: 0.0000 m/s | Reward: -2.4226 | Pos: [-0.934, 0.013, 0.218] | Action: [-1.       -0.550508  0.172522  0.863791 -1.        0.712984]
# Step 4940/5000 | Time: 59.84s | Forward: 0.2407 m/s | Lateral: 0.0000 m/s | Reward: -1.8799 | Pos: [-0.932, 0.014, 0.217] | Action: [-1.        1.        1.       -0.942853  0.227226  1.      ]
# Step 4941/5000 | Time: 59.85s | Forward: 0.1999 m/s | Lateral: 0.0000 m/s | Reward: -2.7991 | Pos: [-0.930, 0.015, 0.217] | Action: [ 1.        0.576436 -0.076895  1.       -1.        0.687437]
# Step 4942/5000 | Time: 59.86s | Forward: 0.2072 m/s | Lateral: 0.0000 m/s | Reward: -2.4242 | Pos: [-0.928, 0.014, 0.216] | Action: [-0.798318 -0.852439  1.       -1.       -0.196583 -1.      ]
# Step 4943/5000 | Time: 59.87s | Forward: 0.2203 m/s | Lateral: 0.0000 m/s | Reward: -2.2068 | Pos: [-0.925, 0.014, 0.215] | Action: [-1.       -0.195853 -0.590447  0.970514  1.       -1.      ]
# Step 4944/5000 | Time: 59.88s | Forward: 0.2261 m/s | Lateral: 0.0000 m/s | Reward: -2.8423 | Pos: [-0.923, 0.013, 0.214] | Action: [ 1.       -0.93945   0.706052  0.281895  0.32053   0.926426]
# Step 4945/5000 | Time: 59.90s | Forward: 0.2700 m/s | Lateral: 0.0000 m/s | Reward: -3.4503 | Pos: [-0.921, 0.011, 0.213] | Action: [ 1.        1.       -0.405589 -0.260878  0.887091 -0.707315]
# Step 4946/5000 | Time: 59.91s | Forward: 0.3238 m/s | Lateral: 0.0000 m/s | Reward: -2.1549 | Pos: [-0.919, 0.008, 0.212] | Action: [ 1.       -1.       -0.864112  0.417159 -0.948198 -0.730369]
# Step 4947/5000 | Time: 59.92s | Forward: 0.2185 m/s | Lateral: 0.0000 m/s | Reward: -3.2542 | Pos: [-0.917, 0.008, 0.211] | Action: [ 0.062922 -0.511096  1.       -0.803453 -0.605773  1.      ]
# Step 4948/5000 | Time: 59.93s | Forward: 0.2350 m/s | Lateral: 0.0000 m/s | Reward: -2.2009 | Pos: [-0.916, 0.010, 0.210] | Action: [ 0.671598 -0.524989 -0.363141  1.       -1.        1.      ]
# Step 4949/5000 | Time: 59.94s | Forward: 0.1860 m/s | Lateral: 0.0000 m/s | Reward: -1.8834 | Pos: [-0.915, 0.011, 0.209] | Action: [ 1.       -1.       -0.606642  1.       -0.572969  0.407139]
# Step 4950/5000 | Time: 59.95s | Forward: 0.1880 m/s | Lateral: 0.0000 m/s | Reward: -1.3567 | Pos: [-0.914, 0.012, 0.207] | Action: [-0.853917 -0.640107 -1.        1.       -1.       -1.      ]
# Step 4951/5000 | Time: 59.96s | Forward: 0.2310 m/s | Lateral: 0.0000 m/s | Reward: -1.6604 | Pos: [-0.913, 0.015, 0.206] | Action: [-0.539473 -1.       -1.        1.       -1.       -0.395955]
# Step 4952/5000 | Time: 59.97s | Forward: 0.2182 m/s | Lateral: 0.0000 m/s | Reward: -1.0283 | Pos: [-0.912, 0.017, 0.206] | Action: [-0.559619 -1.        1.       -1.        1.       -1.      ]
# Step 4953/5000 | Time: 59.98s | Forward: 0.1879 m/s | Lateral: 0.0000 m/s | Reward: -1.0504 | Pos: [-0.912, 0.019, 0.205] | Action: [-1.        1.        1.        0.679572 -0.946101  1.      ]
# Step 4954/5000 | Time: 59.99s | Forward: 0.1116 m/s | Lateral: 0.0000 m/s | Reward: -0.9684 | Pos: [-0.911, 0.020, 0.205] | Action: [-1.        1.        1.        1.       -0.562591  1.      ]
# Step 4955/5000 | Time: 60.01s | Forward: 0.0678 m/s | Lateral: 0.0000 m/s | Reward: -0.5990 | Pos: [-0.911, 0.020, 0.204] | Action: [-1.        1.       -1.        1.        1.        0.888483]
# Step 4956/5000 | Time: 60.02s | Forward: 0.0748 m/s | Lateral: 0.0000 m/s | Reward: -1.5855 | Pos: [-0.911, 0.020, 0.204] | Action: [-1.        1.       -1.       -1.        1.        0.144375]
# Step 4957/5000 | Time: 60.03s | Forward: 0.1431 m/s | Lateral: 0.0000 m/s | Reward: -0.8487 | Pos: [-0.911, 0.019, 0.203] | Action: [ 1. -1. -1.  1.  1. -1.]
# Step 4958/5000 | Time: 60.04s | Forward: 0.2417 m/s | Lateral: 0.0000 m/s | Reward: -0.4784 | Pos: [-0.910, 0.016, 0.202] | Action: [ 1. -1. -1. -1.  1. -1.]
# Step 4959/5000 | Time: 60.05s | Forward: 0.3459 m/s | Lateral: 0.0000 m/s | Reward: -0.6775 | Pos: [-0.910, 0.012, 0.201] | Action: [ 1.       -1.       -0.708522  1.       -1.       -1.      ]
# Step 4960/5000 | Time: 60.06s | Forward: 0.4330 m/s | Lateral: 0.0000 m/s | Reward: -1.4853 | Pos: [-0.910, 0.008, 0.201] | Action: [ 1.       -1.        0.912465  0.738411 -0.431586 -0.808965]
# Step 4961/5000 | Time: 60.07s | Forward: 0.3293 m/s | Lateral: 0.0000 m/s | Reward: -3.3692 | Pos: [-0.910, 0.004, 0.200] | Action: [ 1.        0.78814   1.       -1.        0.108023 -0.249537]
# Step 4962/5000 | Time: 60.08s | Forward: 0.1535 m/s | Lateral: 0.0000 m/s | Reward: -3.4916 | Pos: [-0.910, 0.002, 0.200] | Action: [-1.        1.        1.       -0.400638 -0.103763  1.      ]
# Step 4963/5000 | Time: 60.09s | Forward: 0.0329 m/s | Lateral: 0.0000 m/s | Reward: -3.7548 | Pos: [-0.910, 0.002, 0.200] | Action: [-0.987415 -0.046747  1.       -0.592973 -1.        0.145403]
# Step 4964/5000 | Time: 60.10s | Forward: 0.1384 m/s | Lateral: 0.0000 m/s | Reward: -4.1427 | Pos: [-0.911, 0.004, 0.200] | Action: [ 0.888664  0.02357  -0.729349  1.        0.551706 -1.      ]
# Step 4965/5000 | Time: 60.12s | Forward: 0.1215 m/s | Lateral: 0.0000 m/s | Reward: -0.9201 | Pos: [-0.912, 0.005, 0.199] | Action: [ 1.        1.       -1.        1.        1.       -0.872906]
# Step 4966/5000 | Time: 60.13s | Forward: 0.1813 m/s | Lateral: 0.0000 m/s | Reward: -2.0787 | Pos: [-0.913, 0.006, 0.198] | Action: [ 1.        0.13718  -1.        1.        0.695958  0.929983]
# Step 4967/5000 | Time: 60.14s | Forward: 0.2650 m/s | Lateral: 0.0000 m/s | Reward: -2.7706 | Pos: [-0.914, 0.008, 0.198] | Action: [-0.726171  0.817247 -1.       -0.286151  0.324892 -1.      ]
# Step 4968/5000 | Time: 60.15s | Forward: 0.3516 m/s | Lateral: 0.0000 m/s | Reward: -3.3304 | Pos: [-0.916, 0.012, 0.198] | Action: [ 0.398987 -1.       -0.1563   -1.        0.422199 -0.943048]
# Step 4969/5000 | Time: 60.16s | Forward: 0.3371 m/s | Lateral: 0.0000 m/s | Reward: -2.2829 | Pos: [-0.918, 0.015, 0.198] | Action: [-1.       -0.803563  0.357265 -1.        1.       -1.      ]
# Step 4970/5000 | Time: 60.17s | Forward: 0.2993 m/s | Lateral: 0.0000 m/s | Reward: -3.3253 | Pos: [-0.920, 0.017, 0.197] | Action: [ 0.7578   -0.164296 -1.        0.137435  1.        1.      ]
# Step 4971/5000 | Time: 60.18s | Forward: 0.2675 m/s | Lateral: 0.0000 m/s | Reward: -2.4948 | Pos: [-0.923, 0.019, 0.197] | Action: [-1.        0.488529  1.       -1.       -0.803249 -0.686775]
# Step 4972/5000 | Time: 60.19s | Forward: 0.2288 m/s | Lateral: 0.0000 m/s | Reward: -1.5238 | Pos: [-0.925, 0.020, 0.197] | Action: [-0.379894 -1.        0.783275 -1.       -1.        1.      ]
# Step 4973/5000 | Time: 60.20s | Forward: 0.2155 m/s | Lateral: 0.0000 m/s | Reward: -1.0265 | Pos: [-0.927, 0.020, 0.197] | Action: [ 1.       -0.789429  1.       -1.       -0.707125  1.      ]
# Step 4974/5000 | Time: 60.21s | Forward: 0.2377 m/s | Lateral: 0.0000 m/s | Reward: -1.4740 | Pos: [-0.930, 0.019, 0.197] | Action: [ 1.        1.        0.994595 -0.349834  1.       -1.      ]
# Step 4975/5000 | Time: 60.23s | Forward: 0.1993 m/s | Lateral: 0.0000 m/s | Reward: -3.8428 | Pos: [-0.932, 0.018, 0.197] | Action: [ 1.       -1.       -0.465907  1.       -0.127655 -0.261902]
# Step 4976/5000 | Time: 60.24s | Forward: 0.1688 m/s | Lateral: 0.0000 m/s | Reward: -2.1392 | Pos: [-0.933, 0.017, 0.197] | Action: [ 0.786017 -1.        0.48385   1.       -1.       -0.677035]
# Step 4977/5000 | Time: 60.25s | Forward: 0.1145 m/s | Lateral: 0.0000 m/s | Reward: -1.2394 | Pos: [-0.935, 0.017, 0.197] | Action: [-1.        1.        1.        1.        0.657094  1.      ]
# Step 4978/5000 | Time: 60.26s | Forward: 0.1075 m/s | Lateral: 0.0000 m/s | Reward: -4.9600 | Pos: [-0.936, 0.018, 0.197] | Action: [ 0.088063  1.       -0.182372  0.000839  1.        1.      ]
# Step 4979/5000 | Time: 60.27s | Forward: 0.0774 m/s | Lateral: 0.0000 m/s | Reward: -4.8102 | Pos: [-0.936, 0.018, 0.197] | Action: [ 1.        0.00066  -0.627232  0.131398  1.        0.255671]
# Step 4980/5000 | Time: 60.28s | Forward: 0.0822 m/s | Lateral: 0.0000 m/s | Reward: -3.2820 | Pos: [-0.937, 0.018, 0.197] | Action: [ 1.       -1.        0.65604   1.        1.       -0.361425]
# Step 4981/5000 | Time: 60.29s | Forward: 0.1351 m/s | Lateral: 0.0000 m/s | Reward: -2.9402 | Pos: [-0.938, 0.016, 0.197] | Action: [ 1.      -1.      -1.      -0.26362  0.26508 -0.9653 ]
# Step 4982/5000 | Time: 60.30s | Forward: 0.1399 m/s | Lateral: 0.0000 m/s | Reward: -1.4604 | Pos: [-0.939, 0.015, 0.197] | Action: [ 1.       -1.       -0.949713  1.       -1.        1.      ]
# Step 4983/5000 | Time: 60.31s | Forward: 0.1984 m/s | Lateral: 0.0000 m/s | Reward: -2.2544 | Pos: [-0.939, 0.013, 0.197] | Action: [ 1.       -1.       -0.854793 -0.228937  0.604053 -1.      ]
# Step 4984/5000 | Time: 60.32s | Forward: 0.2639 m/s | Lateral: 0.0000 m/s | Reward: -2.9816 | Pos: [-0.940, 0.010, 0.196] | Action: [ 1.       -1.       -0.478129 -0.784438 -0.652972 -0.13574 ]
# Step 4985/5000 | Time: 60.34s | Forward: 0.3458 m/s | Lateral: 0.0000 m/s | Reward: -2.7803 | Pos: [-0.941, 0.007, 0.196] | Action: [ 0.790352 -0.394751 -1.        1.       -0.2466    1.      ]
# Step 4986/5000 | Time: 60.35s | Forward: 0.3993 m/s | Lateral: 0.0000 m/s | Reward: -3.7640 | Pos: [-0.942, 0.002, 0.195] | Action: [-1.        1.        0.367431 -1.        1.        0.02219 ]
# Step 4987/5000 | Time: 60.36s | Forward: 0.2565 m/s | Lateral: 0.0000 m/s | Reward: -3.0509 | Pos: [-0.943, -0.000, 0.194] | Action: [-1.        1.        1.        0.64753  -0.387642  0.107267]
# Step 4988/5000 | Time: 60.37s | Forward: 0.1831 m/s | Lateral: 0.0000 m/s | Reward: -2.1824 | Pos: [-0.943, 0.001, 0.193] | Action: [-1.        0.367748  1.       -0.701633 -1.        1.      ]
# Step 4989/5000 | Time: 60.38s | Forward: 0.3376 m/s | Lateral: 0.0000 m/s | Reward: -3.3338 | Pos: [-0.943, 0.004, 0.191] | Action: [-1.        1.        0.818421  0.122078 -0.238643 -1.      ]
# Step 4990/5000 | Time: 60.39s | Forward: 0.2829 m/s | Lateral: 0.0000 m/s | Reward: -4.0562 | Pos: [-0.943, 0.007, 0.189] | Action: [ 0.146114 -0.113558  1.       -0.896632 -1.       -1.      ]
# Step 4991/5000 | Time: 60.40s | Forward: 0.3125 m/s | Lateral: 0.0000 m/s | Reward: -2.5179 | Pos: [-0.943, 0.010, 0.188] | Action: [-1.       -1.        1.       -0.727167 -1.       -0.236999]
# Step 4992/5000 | Time: 60.41s | Forward: 0.3184 m/s | Lateral: 0.0000 m/s | Reward: -2.3594 | Pos: [-0.942, 0.013, 0.186] | Action: [ 0.186251 -0.995489  1.       -1.       -1.        1.      ]
# Step 4993/5000 | Time: 60.42s | Forward: 0.3160 m/s | Lateral: 0.0000 m/s | Reward: -2.5729 | Pos: [-0.942, 0.016, 0.184] | Action: [ 1.        0.844986  1.       -1.        0.481358  0.291354]
# Step 4994/5000 | Time: 60.43s | Forward: 0.2407 m/s | Lateral: 0.0000 m/s | Reward: -2.2195 | Pos: [-0.942, 0.018, 0.182] | Action: [ 1.       -1.       -0.401641 -1.        0.482705 -1.      ]
# Step 4995/5000 | Time: 60.45s | Forward: 0.1764 m/s | Lateral: 0.0000 m/s | Reward: -2.6405 | Pos: [-0.941, 0.019, 0.181] | Action: [ 1.       -0.685557 -0.481745 -1.       -0.26213  -1.      ]
# Step 4996/5000 | Time: 60.46s | Forward: 0.1653 m/s | Lateral: 0.0000 m/s | Reward: -1.3183 | Pos: [-0.941, 0.018, 0.179] | Action: [-1.       -1.       -0.904806 -0.49022  -1.       -1.      ]
# Step 4997/5000 | Time: 60.47s | Forward: 0.2164 m/s | Lateral: 0.0000 m/s | Reward: -1.0122 | Pos: [-0.941, 0.017, 0.177] | Action: [-1.  1.  1.  1. -1.  1.]
# Step 4998/5000 | Time: 60.48s | Forward: 0.2843 m/s | Lateral: 0.0000 m/s | Reward: -1.7247 | Pos: [-0.940, 0.014, 0.176] | Action: [-1.        1.        1.        0.270149  0.984172  1.      ]
# Step 4999/5000 | Time: 60.49s | Forward: 0.3273 m/s | Lateral: 0.0000 m/s | Reward: -2.0284 | Pos: [-0.940, 0.011, 0.174] | Action: [0.326732 1.       1.       0.674076 0.715426 1.      ]
# Step 5000/5000 | Time: 60.50s | Forward: 0.2385 m/s | Lateral: 0.0000 m/s | Reward: -2.3414 | Pos: [-0.941, 0.009, 0.172] | Action: [-1.        0.313614  0.516276  1.        0.642096  1.      ]
#
# Total reward over 5000 steps: -11929.3249
# Average reward per step: -2.3859

# %%
# Run a few steps using the trained model
num_steps = 5  # Change this to run more or fewer steps
print(f"\nRunning {num_steps} steps with trained model...")
print("=" * 70)

import io, contextlib

total_reward = 0.0
for i in range(num_steps):
    # Get action from the trained model (deterministic=True for consistent results)
    action, _states = model.predict(obs, deterministic=True)
    # action = np.array([3.4e-3, 3.3e-3, 4.2e-3, 2.6e-3, 3.6e-3, 3.5e-3], dtype=np.float32)
    
    
    # Step the environment
    with contextlib.redirect_stdout(io.StringIO()):
        obs, reward, terminated, truncated, info = env.step(action)
    
    # Accumulate reward
    total_reward += reward
    
    # Print step information (including action)
    action_str = np.array2string(action, precision=6, suppress_small=True)
    status_line = (f"Step {i+1}/{num_steps} | "
                   f"Time: {info['current_time']:.2f}s | "
                   f"Forward: {info['forward_speed']:.4f} m/s | "
                   f"Lateral: {info['lateral_speed']:.4f} m/s | "
                   f"Reward: {reward:.4f} | "
                   f"Pos: [{info['position'][0]:.3f}, {info['position'][1]:.3f}, {info['position'][2]:.3f}] | "
                   f"Action: {action_str}")
    print(status_line)

    # Check if episode ended
    if terminated or truncated:
        print(f"Episode ended at step {i+1}")
        obs, _ = env.reset()
        print("Environment reset for next episode")

# Print summary after loop completes
print(f"\nTotal reward over {num_steps} steps: {total_reward:.4f}")
print(f"Average reward per step: {total_reward/num_steps:.4f}")

# %%
# 4. Save the trained model
model_path = os.path.join("Training", "Saved_Models", "PPO_Snake_Model")
model.save(model_path)
print(f"Training finished! Model saved to {model_path}")

# --- How to load and run the trained model ---
del model
# model = PPO.load(model_path, env=env)
# obs, _ = env.reset()
# for i in range(200):
#     action, _ = model.predict(obs, deterministic=True)
#     obs, reward, terminated, truncated, info = env.step(action)
#     if terminated or truncated:
#         print(f"Episode finished at step {i}")
#         obs, _ = env.reset()

env.close()

# %%
class visualization:
    def __init__(self):
        pass
        
    def trajectory_2d(self,
                      x,
                      z,
                      save_figure=False,
                      filename='trajectory_2d.png'
        ):

        plt.figure()
        plt.plot(x, z, marker='o', linestyle='-')
        plt.xlabel('X')
        plt.ylabel('Z')
        plt.title('X vs Z Endpoint Trajectory')
        plt.grid(True)
        plt.show()
        if save_figure:
            plt.savefig(filename)
        
    def trajectory_3d(self,
                      pts,
                      save_figure=False,
                      filename='trajectory_3d.png'
        ):
        pts = np.asarray(pts)
        fig = plt.figure()
        ax = fig.add_subplot(111, projection='3d')
        ax.plot(pts[:, 0], pts[:, 1], pts[:, 2], marker='o', linewidth=1)
        ax.set_xlabel('X')
        ax.set_ylabel('Y')
        ax.set_zlabel('Z')
        ax.set_title('Trajectory')
        if save_figure:
            plt.savefig(filename)
            
    def current_shape_3d(self,
                        shearable_rod,
                        save_figure=False,
                        filename='current_shape.png'
        ):
        from matplotlib.colors import to_rgb

        fig = plt.figure(figsize=(10, 8), frameon=True, dpi=150)
        ax = fig.add_subplot(111, projection='3d')

        ax.plot(
            shearable_rod.position_collection[0, ...],
            shearable_rod.position_collection[2, ...],
            shearable_rod.position_collection[1, ...],
            c=to_rgb("xkcd:bluish"),
            label="n=" + str(shearable_rod.n_elems),
        )
        ax.set_xlabel('X')
        ax.set_ylabel('Z')
        ax.set_zlabel('Y')
        
        # Set equal aspect ratio for proper scaling
        # Get current axis limits
        xlims = ax.get_xlim()
        ylims = ax.get_ylim()
        zlims = ax.get_zlim()
        
        # Calculate the range for each axis
        x_range = xlims[1] - xlims[0]
        y_range = ylims[1] - ylims[0]
        z_range = zlims[1] - zlims[0]
        
        # Set equal aspect ratio based on the largest range
        max_range = max(x_range, y_range, z_range)
        ax.set_box_aspect([x_range/max_range, y_range/max_range, z_range/max_range])
        
        plt.show()
        if save_figure:
            plt.savefig(filename)
        
    def current_shape_2d(self,
                        shearable_rod,
                        save_figure=False,
                        filename='current_shape.png'
        ):
        from matplotlib.colors import to_rgb

        fig = plt.figure(figsize=(10, 8), frameon=True, dpi=150)
        ax = fig.add_subplot(111)

        ax.plot(
            shearable_rod.position_collection[2, ...],
            shearable_rod.position_collection[0, ...],
            c=to_rgb("xkcd:bluish"),
            label="n=" + str(shearable_rod.n_elems),
        )
        ax.set_xlabel('Z')
        ax.set_ylabel('X')
        plt.show()
        if save_figure:
            plt.savefig(filename)

        
    def velocity_norm_history(self,
                              time: np.ndarray,
                              velocity: np.ndarray,  # shape should be (N, 3)
                              save_figure=False,
                              filename='velocity_norm_history.png'
        ):
        velocity_norm = np.linalg.norm(velocity, axis=1)
        plt.figure()
        plt.plot(time, velocity_norm)
        plt.xlabel('Time')
        plt.ylabel('Velocity Norm')
        plt.title('Velocity Norm History')
        if save_figure:
            plt.savefig(filename)        
        
        
    def plot_video(
        self,
        plot_params: dict,
        video_name: str = "video.mp4",
        fps: int = 60,
        xlim: tuple[float, float] = (0, 4),
        ylim: tuple[float, float] = (-1, 1),
    ) -> None:  # (time step, x/y/z, node)
        import matplotlib.animation as manimation
        from tqdm import tqdm
        positions_over_time = np.array(plot_params["position"])

        num_frames = len(plot_params["time"])
        duration = num_frames / fps
        print(f"Plotting video: {num_frames} frames, {duration:.2f} seconds duration")
        
        FFMpegWriter = manimation.writers["ffmpeg"]
        metadata = dict(title="Movie Test", artist="Matplotlib", comment="Movie support!")
        writer = FFMpegWriter(fps=fps, metadata=metadata)
        fig = plt.figure(figsize=(10, 8), frameon=True, dpi=150)
        ax = fig.add_subplot(111)
        ax.set_xlim(*xlim)
        ax.set_ylim(*ylim)
        ax.set_xlabel("z [m]", fontsize=16)
        ax.set_ylabel("x [m]", fontsize=16)
        rod_lines_2d = ax.plot(positions_over_time[0][2], positions_over_time[0][0])[0]
        # plt.axis("equal")
        with writer.saving(fig, video_name, dpi=150):
            for time in tqdm(range(1, len(plot_params["time"]))):
                rod_lines_2d.set_xdata([positions_over_time[time][2]])
                rod_lines_2d.set_ydata([positions_over_time[time][0]])
                writer.grab_frame()

        # Be a good boy and close figures
        # https://stackoverflow.com/a/37451036
        # plt.close(fig) alone does not suffice
        # See https://github.com/matplotlib/matplotlib/issues/8560/
        plt.close(plt.gcf())

    def plot_video_limited(
        self,
        plot_params: dict,
        video_name: str = "video_limited.mp4",
        max_samples: int = 3000,
        xlim: tuple[float, float] = (0, 4),
        ylim: tuple[float, float] = (-1, 1),
    ) -> None:
        import matplotlib.animation as manimation
        from tqdm import tqdm

        times = np.asarray(plot_params["time"])
        positions_over_time = np.asarray(plot_params["position"])

        if times.ndim == 0 or len(times) == 0:
            raise ValueError("plot_params['time'] must contain at least one entry.")
        if positions_over_time.shape[0] != len(times):
            raise ValueError(
                "First dimension of plot_params['position'] must match length of plot_params['time']."
            )

        total_available = len(times)
        if total_available <= max_samples:
            indices = np.arange(total_available, dtype=int)
        else:
            indices = np.linspace(0, total_available - 1, max_samples)
            indices = np.round(indices).astype(int)
            indices[0] = 0
            indices[-1] = total_available - 1
            indices = np.unique(indices)
            if indices[0] != 0:
                indices = np.insert(indices, 0, 0)
            if indices[-1] != total_available - 1:
                indices = np.append(indices, total_available - 1)

        subsampled_times = times[indices]
        subsampled_positions = positions_over_time[indices]
        num_frames = len(subsampled_times)

        if num_frames == 0:
            raise ValueError("No frames selected for plotting.")

        total_time = float(subsampled_times[-1] - subsampled_times[0])
        if total_time > 0.0 and num_frames > 0:
            computed_fps = num_frames / total_time
        else:
            computed_fps = 1.0

        if computed_fps <= 0.0:
            computed_fps = 1.0

        duration = num_frames / computed_fps
        print(
            f"Plotting limited video: using {num_frames} of {total_available} frames, "
            f"{computed_fps:.2f} fps, {duration:.2f} seconds duration"
        )

        FFMpegWriter = manimation.writers["ffmpeg"]
        metadata = dict(title="Movie Test", artist="Matplotlib", comment="Movie support!")
        writer = FFMpegWriter(fps=computed_fps, metadata=metadata)
        fig = plt.figure(figsize=(10, 8), frameon=True, dpi=150)
        ax = fig.add_subplot(111)
        ax.set_xlim(*xlim)
        ax.set_ylim(*ylim)
        ax.set_xlabel("z [m]", fontsize=16)
        ax.set_ylabel("x [m]", fontsize=16)
        rod_lines_2d = ax.plot(
            subsampled_positions[0][2], subsampled_positions[0][0]
        )[0]
        with writer.saving(fig, video_name, dpi=150):
            for frame_idx in tqdm(range(1, num_frames)):
                rod_lines_2d.set_xdata([subsampled_positions[frame_idx][2]])
                rod_lines_2d.set_ydata([subsampled_positions[frame_idx][0]])
                writer.grab_frame()

        plt.close(plt.gcf())

    def plot_video_auto_limits(
        self,
        plot_params: dict,
        video_name: str = "video_auto_limits.mp4",
        max_samples: int = 3000,
        padding_ratio: float = 0.05,
    ) -> None:
        positions_over_time = np.asarray(plot_params["position"])

        if positions_over_time.shape[0] == 0:
            raise ValueError("plot_params['position'] must contain at least one entry.")

        if positions_over_time.ndim < 2:
            raise ValueError("plot_params['position'] must have at least two dimensions.")

        if positions_over_time.shape[1] == 3:
            oriented_positions = positions_over_time
        elif positions_over_time.shape[-1] == 3:
            oriented_positions = np.moveaxis(positions_over_time, -1, 1)
        else:
            raise ValueError(
                "plot_params['position'] must include a coordinate axis of length 3."
            )

        num_frames = oriented_positions.shape[0]
        reshaped_positions = oriented_positions.reshape(num_frames, 3, -1)
        z_values = reshaped_positions[:, 2, :].ravel()
        x_values = reshaped_positions[:, 0, :].ravel()

        finite_mask = np.isfinite(z_values) & np.isfinite(x_values)
        if not np.any(finite_mask):
            raise ValueError(
                "plot_params['position'] must contain finite values for x and z coordinates."
            )

        z_values = z_values[finite_mask]
        x_values = x_values[finite_mask]

        z_min = float(z_values.min())
        z_max = float(z_values.max())
        x_min = float(x_values.min())
        x_max = float(x_values.max())

        if np.isclose(z_min, z_max):
            z_center = 0.5 * (z_min + z_max)
            z_half_range = max(abs(z_center) * padding_ratio, 1e-3)
            xlim = (z_center - z_half_range, z_center + z_half_range)
        else:
            padding_z = padding_ratio * (z_max - z_min)
            xlim = (z_min - padding_z, z_max + padding_z)

        if np.isclose(x_min, x_max):
            x_center = 0.5 * (x_min + x_max)
            x_half_range = max(abs(x_center) * padding_ratio, 1e-3)
            ylim = (x_center - x_half_range, x_center + x_half_range)
        else:
            padding_x = padding_ratio * (x_max - x_min)
            ylim = (x_min - padding_x, x_max + padding_x)

        self.plot_video_limited(
            plot_params=plot_params,
            video_name=video_name,
            max_samples=max_samples,
            xlim=xlim,
            ylim=ylim,
        )
